# %% [markdown]
# # TODO:
# * Implement stacking (ensembling technique)
# * Use xgboost, catboost, lightgbm and keras and logistic regression as base models
# * Use linear regression with regularization (fine tune the regularization parameter with optuna) and tackle the task as regression with target values either being 0 or 1 and feature values of meta data being the probabilities predicted by our base models

# %% [markdown]
# # REMOVE ALL THE NEW ADDED FEATURES
# ## The keras tuned model achieved a score of 87.7 with no feature engineering

# %%
import numpy as np
import pandas as pd
import os
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from pathlib import Path
import xgboost as xgb
import lightgbm as lgbm
import catboost
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.metrics import roc_auc_score
from sklearn.linear_model import LogisticRegression
from IPython.display import display
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
import optuna
from optuna.samplers import TPESampler
from optuna.integration import XGBoostPruningCallback
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler

# %%
from warnings import filterwarnings
filterwarnings('ignore')

# %% [markdown]
# # Loading Data

# %%
BASE_DIR = Path("/kaggle/input/playground-series-s3e2/")

train = pd.read_csv(BASE_DIR / "train.csv").drop(columns="id")
test = pd.read_csv(BASE_DIR / "test.csv").drop(columns="id")

# %% [markdown]
# # Preprocessing

# %%
df = pd.concat([train.drop(columns=["stroke"]), test], axis=0).reset_index(drop=True)
df.head()
# Out:
#    gender   age  hypertension  heart_disease ever_married work_type  \
# 0    Male  28.0             0              0          Yes   Private
# 1    Male  33.0             0              0          Yes   Private
# 2  Female  42.0             0              0          Yes   Private
# 3    Male  56.0             0              0          Yes   Private
# 4  Female  24.0             0              0           No   Private
#
#   Residence_type  avg_glucose_level   bmi   smoking_status
# 0          Urban              79.53  31.1     never smoked
# 1          Rural              78.44  23.9  formerly smoked
# 2          Rural             103.00  40.3          Unknown
# 3          Urban              64.87  28.8     never smoked
# 4          Rural              73.36  28.8     never smoked

# %% [markdown]
# # Encoding - One hot

# %%
df = pd.get_dummies(df)
df.head(3)
# Out:
#     age  hypertension  heart_disease  avg_glucose_level   bmi  gender_Female  \
# 0  28.0             0              0              79.53  31.1              0
# 1  33.0             0              0              78.44  23.9              0
# 2  42.0             0              0             103.00  40.3              1
#
#    gender_Male  gender_Other  ever_married_No  ever_married_Yes  ...  \
# 0            1             0                0                 1  ...
# 1            1             0                0                 1  ...
# 2            0             0                0                 1  ...
#
#    work_type_Never_worked  work_type_Private  work_type_Self-employed  \
# 0                       0                  1                        0
# 1                       0                  1                        0
# 2                       0                  1                        0
#
#    work_type_children  Residence_type_Rural  Residence_type_Urban  \
# 0                   0                     0                     1
# 1                   0                     1                     0
# 2                   0                     1                     0
#
#    smoking_status_Unknown  smoking_status_formerly smoked  \
# 0                       0                               0
# 1                       0                               1
# 2                       1                               0
#
#    smoking_status_never smoked  smoking_status_smokes
# 0                            1                      0
# 1                            0                      0
# 2                            0                      0
#
# [3 rows x 21 columns]

# %% [markdown]
# # Preprocessing v2

# %%
X = df.iloc[:-len(test), :]
test_new = df.iloc[-len(test):, :]
y = train.stroke

# %%
type(X)

# %% [markdown]
# # Before we ensebmle, let's first finetune individual models and to get the optimized parameters for them

# %%
def cross_validate(X, y, model):
    kf = StratifiedKFold(n_splits=8, shuffle=True, random_state=1337)
    
    cv_scores = []
    
    for fold, (train_idx, val_idx) in enumerate(kf.split(X, y)):
        X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
        y_train, y_val = y.iloc[train_idx], y.iloc[val_idx]
                
        # training
        model.fit(X_train, y_train, verbose=0)

        # predicting
        y_pred = model.predict_proba(X_val)[:, 1]
        
        auc = roc_auc_score(y_val, y_pred)
        
        print(f"Fold: {fold} \t auc: {auc}")
        
        cv_scores.append(auc)
    
    avg_auc = np.mean(cv_scores)
    print(f"Avg AUC: {avg_auc}")

# %% [markdown]
# ## Finetuning Logsitic Regression

# %%
# def objective(trial, X, y):
#     params = {
#         "solver": trial.suggest_categorical("solver", ["liblinear", "newton-cg", "saga", "lbfgs"]),
#         "C": trial.suggest_loguniform("C", 0.01, 100.0),
#         "tol": trial.suggest_loguniform("tol", 1e-6, 1e-2),
#         "max_iter": trial.suggest_int("max_iter", 100, 1000),
#     }
        
#     if params["solver"] in ["newton-cg", "lbfgs"]:
#         params["penalty"] = "l2"
        
#     elif params["solver"] == "liblinear":
#         params["penalty"] =  trial.suggest_categorical("penalty_liblinear", ["l1","l2"])
    
#     elif params["solver"] == "saga":
#         params["penalty"] =  trial.suggest_categorical("penalty_saga", ["l1","l2","elasticnet"])
        
#         # saga also needs anothe parameter l1_ratio which ranges in 0-1
#         params["l1_ratio"] = trial.suggest_loguniform("l1_ratio", 0.00001, 1)
        
#         # saga also likes it's features to be scaled to converge so let's scale our data
#         sc = StandardScaler()
#         X = sc.fit_transform(X)
        
#     # lets cross validate
#     cv = StratifiedKFold(n_splits=8, shuffle=True, random_state=1337)
    
#     cv_scores = []
#     for fold, (train_idx, test_idx) in enumerate(cv.split(X, y)):
#         # since we scale our dataset also, that converts it into a numpy ndarray
#         # and hence it won't have iloc func that pandas dataframe has.
#         # so let's check for the datatype of X first and then slice
#         if type(X) == pd.core.frame.DataFrame:
#             X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
#             y_train, y_test = y[train_idx], y[test_idx]
#         else:
#             X_train, X_test = X[train_idx], X[test_idx]
#             y_train, y_test = y[train_idx], y[test_idx]
            
        
#         model = LogisticRegression(**params)       
#         model.fit(X_train, y_train)
        
#         y_pred = model.predict_proba(X_test)[:, 1]
#         cv_scores.append(roc_auc_score(y_test, y_pred))
    
#     auc = np.mean(cv_scores)
#     return auc

# %%
# lr_study = optuna.create_study(direction="maximize", study_name="linear regression tuning")
# func = lambda trial: objective(trial, X, y)
# lr_study.optimize(func, n_trials=100, show_progress_bar=True)
# Out:
# [I 2023-01-15 14:03:59,120] A new study created in memory with name: linear regression tuning
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2023-01-15 14:04:03,540] Trial 0 finished with value: 0.8832357853760888 and parameters: {'solver': 'newton-cg', 'C': 3.2028242020646847, 'tol': 0.0013055534435784677, 'max_iter': 442}. Best is trial 0 with value: 0.8832357853760888.
# [I 2023-01-15 14:04:08,621] Trial 1 finished with value: 0.883240961859669 and parameters: {'solver': 'newton-cg', 'C': 5.820092204893791, 'tol': 0.004606852242096995, 'max_iter': 911}. Best is trial 1 with value: 0.883240961859669.
# [I 2023-01-15 14:04:10,530] Trial 2 finished with value: 0.858588821556258 and parameters: {'solver': 'liblinear', 'C': 0.020367227539703017, 'tol': 2.5334999744522436e-05, 'max_iter': 734, 'penalty_liblinear': 'l1'}. Best is trial 1 with value: 0.883240961859669.
# [I 2023-01-15 14:04:28,469] Trial 3 finished with value: 0.8833229228496887 and parameters: {'solver': 'saga', 'C': 0.737476710003354, 'tol': 0.00023418637012104457, 'max_iter': 718, 'penalty_saga': 'l2', 'l1_ratio': 0.6741831967062505}. Best is trial 3 with value: 0.8833229228496887.
. Best is trial 66 with value: 0.8837284140634706.
# [I 2023-01-15 14:24:30,474] Trial 90 finished with value: 0.8831037850447938 and parameters: {'solver': 'newton-cg', 'C': 0.0345521191844384, 'tol': 0.00023130281137441743, 'max_iter': 504}. Best is trial 66 with value: 0.8837284140634706.
# [I 2023-01-15 14:24:46,589] Trial 91 finished with value: 0.883696492414726 and parameters: {'solver': 'saga', 'C': 0.06691898588686726, 'tol': 0.0003212984281970033, 'max_iter': 488, 'penalty_saga': 'l1', 'l1_ratio': 0.0001040402018664478}. Best is trial 66 with value: 0.8837284140634706.
# [I 2023-01-15 14:24:58,990] Trial 92 finished with value: 0.8835386096655301 and parameters: {'solver': 'saga', 'C': 0.05003274143024346, 'tol': 0.0006019948284855794, 'max_iter': 479, 'penalty_saga': 'l1', 'l1_ratio': 0.00011958691867837761}. Best is trial 66 with value: 0.8837284140634706.
# [I 2023-01-15 14:25:14,143] Trial 93 finished with value: 0.88362315889734 and parameters: {'solver': 'saga', 'C': 0.07080378960110027, 'tol': 0.00037946564278320264, 'max_iter': 529, 'penalty_saga': 'l1', 'l1_ratio': 0.0003095826661552608}. Best is trial 66 with value: 0.8837284140634706.
# [I 2023-01-15 14:25:29,391] Trial 94 finished with value: 0.8836222961500766 and parameters: {'solver': 'saga', 'C': 0.07124360926229611, 'tol': 0.00037008684415095253, 'max_iter': 585, 'penalty_saga': 'l1', 'l1_ratio': 0.00030165299936490313}. Best is trial 66 with value: 0.8837284140634706.
# [I 2023-01-15 14:25:44,702] Trial 95 finished with value: 0.8836257471391301 and parameters: {'solver': 'saga', 'C': 0.07048837289342713, 'tol': 0.00037464730728510186, 'max_iter': 681, 'penalty_saga': 'l1', 'l1_ratio': 0.0003773955250395478}. Best is trial 66 with value: 0.8837284140634706.
# [I 2023-01-15 14:25:59,215] Trial 96 finished with value: 0.8836369628535539 and parameters: {'solver': 'saga', 'C': 0.06992284617376378, 'tol': 0.0004202595986386999, 'max_iter': 692, 'penalty_saga': 'l1', 'l1_ratio': 0.00038489274172324084}. Best is trial 66 with value: 0.8837284140634706.
# [I 2023-01-15 14:26:11,387] Trial 97 finished with value: 0.8827931960299822 and parameters: {'solver': 'saga', 'C': 0.027204716994459022, 'tol': 0.0005356758560127788, 'max_iter': 727, 'penalty_saga': 'l1', 'l1_ratio': 0.00038894966379467925}. Best is trial 66 with value: 0.8837284140634706.
# [I 2023-01-15 14:26:22,417] Trial 98 finished with value: 0.8834989232914152 and parameters: {'solver': 'saga', 'C': 0.06769464440122604, 'tol': 0.0008219344168300634, 'max_iter': 706, 'penalty_saga': 'l1', 'l1_ratio': 0.0012739188805595302}. Best is trial 66 with value: 0.8837284140634706.
# [I 2023-01-15 14:26:36,650] Trial 99 finished with value: 0.883587786259542 and parameters: {'solver': 'saga', 'C': 0.08331561777632866, 'tol': 0.00045667001988769333, 'max_iter': 678, 'penalty_saga': 'l1', 'l1_ratio': 9.901686381407083e-05}. Best is trial 66 with value: 0.8837284140634706.

# %%
# lr_study.best_value
# Out:
# 0.8837284140634706

# %%
# lr_study.best_params
# Out:
# {'solver': 'saga',
#  'C': 0.07655860626453208,
#  'tol': 0.00011268918749381429,
#  'max_iter': 484,
#  'penalty_saga': 'l1',
#  'l1_ratio': 0.012007897837476486}

# %% [markdown]
# ## Finetuning XGBoost

# %%
# # we already have fintuned params for xgboost as following
# xgb_params = {'n_estimators': 272,
#                  'max_depth': 4,
#                  'learning_rate': 0.07360332417334109,
#                  'min_child_weight': 1,
#                  'gamma': 0.05180472121817407,
#                  'subsample': 0.41981696676590474,
#                  'colsample_bytree': 0.730818203141452,
#                  'reg_alpha': 0.0005268315833160329,
#                  'reg_lambda': 0.0007997627184403383}

# %% [markdown]
# ## Finetuning LightGBM

# %%
# from optuna.integration import LightGBMPruningCallback

# def objective(trial, X, y):
#     param_grid = {
# #         "device_type": trial.suggest_categorical("device_type", ['gpu']),
#         "is_unbalance": True,
#         "n_estimators": trial.suggest_int("n_estimators", 100, 2000),
#         "num_rounds": trial.suggest_int("num_rounds", 100, 500),
#         "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3),
#         "num_leaves": trial.suggest_int("num_leaves", 20, 300),
#         "max_depth": trial.suggest_int("max_depth", 2, 12),
#         "min_data_in_leaf": trial.suggest_int("min_data_in_leaf", 20, 1000),
#         "lambda_l1": trial.suggest_loguniform('lambda_l1', 0.00001, 1.0),
#         "lambda_l2": trial.suggest_loguniform('lambda_l2', 0.00001, 1.0),
#         "min_gain_to_split": trial.suggest_float("min_gain_to_split", 0, 15),
#         "bagging_fraction":  trial.suggest_loguniform('bagging_fraction', 0.2, 1.0),
#         "feature_fraction": trial.suggest_loguniform('feature_fraction', 0.2, 1.0),
#     }

#     cv = StratifiedKFold(n_splits=8, shuffle=True, random_state=1337)

#     cv_scores = np.empty(8)
#     for fold, (train_idx, test_idx) in enumerate(cv.split(X, y)):
#         X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
#         y_train, y_test = y[train_idx], y[test_idx]

#         model = lgbm.LGBMClassifier(objective="binary", **param_grid)
#         model.fit(
#             X_train,
#             y_train,
#             eval_set=[(X_test, y_test)],
#             eval_metric="auc",
#             early_stopping_rounds=100,
#             verbose=0,
#             callbacks=[
#                 LightGBMPruningCallback(trial, "auc")
#             ],  # Add a pruning callback
#         )
#         y_preds = model.predict_proba(X_test)[:, 1]
#         cv_scores[fold] = roc_auc_score(y_test, y_preds)
    
#     auc = np.mean(cv_scores)
#     print(f"AVG CV AUC: \t {auc}")

#     return auc

# %%
# study = optuna.create_study(direction="maximize", study_name="LGBM Tuning")
# func = lambda trial: objective(trial, X, y)
# study.optimize(func, n_trials=100, show_progress_bar=True)

# %%
# study.best_value

# %%
# study.best_params

# %%
lgbm_params = study.best_params

# %% [markdown]
# # CatBoost

# %%
# def objective(trial, X, y):
#     param = {
#         "loss_function": trial.suggest_categorical("loss_function", ["CrossEntropy"]),
#         "learning_rate": trial.suggest_loguniform("learning_rate", 1e-5, 1e0),
#         "l2_leaf_reg": trial.suggest_loguniform("l2_leaf_reg", 1e-2, 1e0),
#         "colsample_bylevel": trial.suggest_float("colsample_bylevel", 0.01, 0.1),
#         "depth": trial.suggest_int("depth", 1, 10),
#         "boosting_type": trial.suggest_categorical("boosting_type", ["Ordered", "Plain"]),
#         "bootstrap_type": trial.suggest_categorical("bootstrap_type", ["Bayesian", "Bernoulli", "MVS"]),
#         "min_data_in_leaf": trial.suggest_int("min_data_in_leaf", 2, 20),
#         "one_hot_max_size": trial.suggest_int("one_hot_max_size", 2, 20),  
#     }
#     # Conditional Hyper-Parameters
#     if param["bootstrap_type"] == "Bayesian":
#         param["bagging_temperature"] = trial.suggest_float("bagging_temperature", 0, 10)
#     elif param["bootstrap_type"] == "Bernoulli":
#         param["subsample"] = trial.suggest_float("subsample", 0.1, 1)
    
#     cv = StratifiedKFold(n_splits=8, shuffle=True, random_state=1337)

#     cv_scores = np.empty(8)
#     for fold, (train_idx, test_idx) in enumerate(cv.split(X, y)):
#         X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
#         y_train, y_test = y[train_idx], y[test_idx]

#         cat_model = catboost.CatBoostClassifier(**param)
#         cat_model.fit(X_train, y_train, eval_set=[(X_test, y_test)], verbose=0, early_stopping_rounds=100)
        
#         y_preds = cat_model.predict_proba(X_test)[:, 1]
#         cv_scores[fold] = roc_auc_score(y_test, y_preds)
    
#     auc = np.mean(cv_scores)
#     print(f"AVG CV AUC: \t {auc}")
#     return auc

# %%
# cat_study = optuna.create_study(direction="maximize", study_name="catboost tuning")
# func = lambda trial: objective(trial, X, y)
# cat_study.optimize(func, n_trials=100, show_progress_bar=True)
# Out:
# [I 2023-01-15 14:32:46,376] A new study created in memory with name: catboost tuning
#   0%|          | 0/100 [00:00<?, ?it/s]
# AVG CV AUC: 	 0.8433121557638419
# [I 2023-01-15 14:34:00,968] Trial 0 finished with value: 0.8433121557638419 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.00038667366894423077, 'l2_leaf_reg': 0.28344531162113895, 'colsample_bylevel': 0.035192082523750806, 'depth': 8, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 16, 'one_hot_max_size': 19}. Best is trial 0 with value: 0.8433121557638419.
# AVG CV AUC: 	 0.8427159974048563
# [I 2023-01-15 14:35:06,903] Trial 1 finished with value: 0.8427159974048563 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.004295360948863174, 'l2_leaf_reg': 0.38536540688936655, 'colsample_bylevel': 0.02657439645438508, 'depth': 6, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'min_data_in_leaf': 5, 'one_hot_max_size': 20, 'bagging_temperature': 7.189931196909804}. Best is trial 0 with value: 0.8433121557638419.
# AVG CV AUC: 	 0.8868731278384384
# [I 2023-01-15 14:35:42,686] Trial 2 finished with value: 0.8868731278384384 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.10479536077365939, 'l2_leaf_reg': 0.016483642872707868, 'colsample_bylevel': 0.07692707207099202, 'depth': 2, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 10, 'one_hot_max_size': 13, 'subsample': 0.8180720784381502}. Best is trial 2 with value: 0.8868731278384384.
# AVG CV AUC: 	 0.8567330521927585
# [I 2023-01-15 14:36:57,992] Trial 3 finished with value: 0.8567330521927585 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.0032601762865966306, 'l2_leaf_reg': 0.15937174815361912, 'colsample_bylevel': 0.06460724096358152, 'depth': 3, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 9, 'one_hot_max_size': 5}. Best is trial 2 with value: 0.8868731278384384.
# AVG CV AUC: 	 0.8580370946813356
# [I 2023-01-15 14:38:06,669] Trial 4 finished with value: 0.8580370946813356 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.010514791112859708, 'l2_leaf_reg': 0.04061385447182975, 'colsample_bylevel': 0.035751788905313435, 'depth': 9, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 5, 'one_hot_max_size': 8}. Best is trial 2 with value: 0.8868731278384384.
# AVG CV AUC: 	 0.839393557693635
# [I 2023-01-15 14:39:23,920] Trial 5 finished with value: 0.839393557693635 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 3.185270489077288e-05, 'l2_leaf_reg': 0.03446222415709053, 'colsample_bylevel': 0.04178688558827546, 'depth': 7, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 13, 'one_hot_max_size': 20}. Best is trial 2 with value: 0.8868731278384384.
# AVG CV AUC: 	 0.88317711856218
# [I 2023-01-15 14:40:38,685] Trial 6 finished with value: 0.88317711856218 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.019653800011098115, 'l2_leaf_reg': 0.37927878261739184, 'colsample_bylevel': 0.09497767062135334, 'depth': 7, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 9, 'one_hot_max_size': 6, 'subsample': 0.6464132795174218}. Best is trial 2 with value: 0.8868731278384384.
# AVG CV AUC: 	 0.8742153313639689
# [I 2023-01-15 14:41:35,557] Trial 7 finished with value: 0.8742153313639689 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.03907988797844938, 'l2_leaf_reg': 0.7600426917970109, 'colsample_bylevel': 0.08626007179936711, 'depth': 7, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'min_data_in_leaf': 16, 'one_hot_max_size': 10, 'bagging_temperature': 8.17386025058279}. Best is trial 2 with value: 0.8868731278384384.
# AVG CV AUC: 	 0.8363221774360532
# [I 2023-01-15 14:41:52,571] Trial 8 finished with value: 0.8363221774360532 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.004611614790294124, 'l2_leaf_reg': 0.10336116978769885, 'colsample_bylevel': 0.018027105424029764, 'depth': 3, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 6, 'one_hot_max_size': 15}. Best is trial 2 with value: 0.8868731278384384.
# AVG CV AUC: 	 0.882095664867551
# [I 2023-01-15 14:41:55,869] Trial 9 finished with value: 0.882095664867551 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.7676536709375328, 'l2_leaf_reg': 0.25824163798359673, 'colsample_bylevel': 0.09073253593192017, 'depth': 3, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 9, 'one_hot_max_size': 19}. Best is trial 2 with value: 0.8868731278384384.
# AVG CV AUC: 	 0.8883760335712216
# [I 2023-01-15 14:42:02,155] Trial 10 finished with value: 0.8883760335712216 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.44527715188810124, 'l2_leaf_reg': 0.01713496150582082, 'colsample_bylevel': 0.06827976969134689, 'depth': 1, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 20, 'one_hot_max_size': 14, 'subsample': 0.989182205223423}. Best is trial 10 with value: 0.8883760335712216.
# AVG CV AUC: 	 0.8872622268542164
# [I 2023-01-15 14:42:06,149] Trial 11 finished with value: 0.8872622268542164 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.9165266489473787, 'l2_leaf_reg': 0.011378535435640148, 'colsample_bylevel': 0.06318851497266306, 'depth': 1, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 18, 'one_hot_max_size': 14, 'subsample': 0.9928710522448319}. Best is trial 10 with value: 0.8883760335712216.
# AVG CV AUC: 	 0.8876038747705092
# [I 2023-01-15 14:42:11,797] Trial 12 finished with value: 0.8876038747705092 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.576586930072347, 'l2_leaf_reg': 0.012057380324512394, 'colsample_bylevel': 0.05859730499945378, 'depth': 1, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 20, 'one_hot_max_size': 15, 'subsample': 0.9866232544273161}. Best is trial 10 with value: 0.8883760335712216.
# AVG CV AUC: 	 0.8832189618044533
# [I 2023-01-15 14:42:22,108] Trial 13 finished with value: 0.8832189618044533 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.11836890614991723, 'l2_leaf_reg': 0.026797600235601286, 'colsample_bylevel': 0.05365612789361524, 'depth': 1, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 19, 'one_hot_max_size': 16, 'subsample': 0.18020993086326964}. Best is trial 10 with value: 0.8883760335712216.
# AVG CV AUC: 	 0.8815555850806842
# [I 2023-01-15 14:42:26,610] Trial 14 finished with value: 0.8815555850806842 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.24011741122380723, 'l2_leaf_reg': 0.010912733445689732, 'colsample_bylevel': 0.07221934972545713, 'depth': 4, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 20, 'one_hot_max_size': 11, 'subsample': 0.9518157757139428}. Best is trial 10 with value: 0.8883760335712216.
# AVG CV AUC: 	 0.8453486706790165
# [I 2023-01-15 14:42:45,716] Trial 15 finished with value: 0.8453486706790165 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.0002615801122362288, 'l2_leaf_reg': 0.06176283529112775, 'colsample_bylevel': 0.047553699678901176, 'depth': 5, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 14, 'one_hot_max_size': 17, 'subsample': 0.6838374583710879}. Best is trial 10 with value: 0.8883760335712216.
# AVG CV AUC: 	 0.8853973986444514
# [I 2023-01-15 14:42:54,000] Trial 16 finished with value: 0.8853973986444514 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.2441703228960118, 'l2_leaf_reg': 0.020470403713319537, 'colsample_bylevel': 0.060708116374222396, 'depth': 1, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 2, 'one_hot_max_size': 2, 'subsample': 0.38681391276820787}. Best is trial 10 with value: 0.8883760335712216.
# AVG CV AUC: 	 0.8565993263669367
# [I 2023-01-15 14:43:20,331] Trial 17 finished with value: 0.8565993263669367 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.00042295506542712913, 'l2_leaf_reg': 0.05684794997704934, 'colsample_bylevel': 0.08015860443983058, 'depth': 10, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'min_data_in_leaf': 17, 'one_hot_max_size': 13, 'bagging_temperature': 0.012759879696452536}. Best is trial 10 with value: 0.8883760335712216.
# AVG CV AUC: 	 0.8842231996190109
# [I 2023-01-15 14:43:35,207] Trial 18 finished with value: 0.8842231996190109 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.05592682544528647, 'l2_leaf_reg': 0.01683571911236872, 'colsample_bylevel': 0.052583055935304025, 'depth': 2, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 20, 'one_hot_max_size': 11, 'subsample': 0.8211870535012347}. Best is trial 10 with value: 0.8883760335712216.
# AVG CV AUC: 	 0.8739724680093315
# [I 2023-01-15 14:43:38,462] Trial 19 finished with value: 0.8739724680093315 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.39526978832106274, 'l2_leaf_reg': 0.08156157117246246, 'colsample_bylevel': 0.06898856465345879, 'depth': 5, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 13, 'one_hot_max_size': 17, 'subsample': 0.46683634398670926}. Best is trial 10 with value: 0.8883760335712216.
# AVG CV AUC: 	 0.8458175738166558
# [I 2023-01-15 14:43:58,223] Trial 20 finished with value: 0.8458175738166558 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 4.3571875996556814e-05, 'l2_leaf_reg': 0.010085097061075873, 'colsample_bylevel': 0.09991617697993524, 'depth': 2, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 15, 'one_hot_max_size': 9, 'subsample': 0.8561769562580198}. Best is trial 10 with value: 0.8883760335712216.
# AVG CV AUC: 	 0.8886163086840688
# [I 2023-01-15 14:44:03,694] Trial 21 finished with value: 0.8886163086840688 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.7611165319863433, 'l2_leaf_reg': 0.014250721124770624, 'colsample_bylevel': 0.061218122768953775, 'depth': 1, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 18, 'one_hot_max_size': 14, 'subsample': 0.9972814280760031}. Best is trial 21 with value: 0.8886163086840688.
# AVG CV AUC: 	 0.8883402295597917
# [I 2023-01-15 14:44:08,854] Trial 22 finished with value: 0.8883402295597917 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.856281005415478, 'l2_leaf_reg': 0.023401611800191267, 'colsample_bylevel': 0.08186419013315954, 'depth': 1, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 18, 'one_hot_max_size': 13, 'subsample': 0.9829238901597895}. Best is trial 21 with value: 0.8886163086840688.
# AVG CV AUC: 	 0.8870223831150008
# [I 2023-01-15 14:44:15,350] Trial 23 finished with value: 0.8870223831150008 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.15357346824259288, 'l2_leaf_reg': 0.025637023577228177, 'colsample_bylevel': 0.08216474435984597, 'depth': 2, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 18, 'one_hot_max_size': 12, 'subsample': 0.860534307729697}. Best is trial 21 with value: 0.8886163086840688.
# AVG CV AUC: 	 0.8819334683820383
# [I 2023-01-15 14:44:28,404] Trial 24 finished with value: 0.8819334683820383 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.039590330186847274, 'l2_leaf_reg': 0.04112950704109402, 'colsample_bylevel': 0.07155301597849645, 'depth': 4, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 18, 'one_hot_max_size': 13, 'subsample': 0.7028011727554182}. Best is trial 21 with value: 0.8886163086840688.
# AVG CV AUC: 	 0.8850799076515329
# [I 2023-01-15 14:44:34,596] Trial 25 finished with value: 0.8850799076515329 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.3933937014486196, 'l2_leaf_reg': 0.0172894312361555, 'colsample_bylevel': 0.07688312135385601, 'depth': 1, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'min_data_in_leaf': 16, 'one_hot_max_size': 17, 'bagging_temperature': 2.295886667768474}. Best is trial 21 with value: 0.8886163086840688.
# AVG CV AUC: 	 0.8744210965862815
# [I 2023-01-15 14:44:37,426] Trial 26 finished with value: 0.8744210965862815 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.8776623918111692, 'l2_leaf_reg': 0.0270970577210656, 'colsample_bylevel': 0.08858124093552579, 'depth': 4, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 12, 'one_hot_max_size': 15, 'subsample': 0.9074250661960714}. Best is trial 21 with value: 0.8886163086840688.
# AVG CV AUC: 	 0.8858494782104551
# [I 2023-01-15 14:44:50,869] Trial 27 finished with value: 0.8858494782104551 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0
 'depth': 7, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 20, 'one_hot_max_size': 3, 'subsample': 0.8616786415343441}. Best is trial 21 with value: 0.8886163086840688.
# AVG CV AUC: 	 0.8542668891404277
# [I 2023-01-15 14:59:22,874] Trial 99 finished with value: 0.8542668891404277 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.001978343509600742, 'l2_leaf_reg': 0.11242481009208773, 'colsample_bylevel': 0.08912702979005492, 'depth': 1, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 13, 'one_hot_max_size': 13, 'subsample': 0.5078973657002788}. Best is trial 21 with value: 0.8886163086840688.

# %%
# cat_study.best_value
# Out:
# 0.8886163086840688

# %%
# cat_study.best_params
# Out:
# {'loss_function': 'CrossEntropy',
#  'learning_rate': 0.7611165319863433,
#  'l2_leaf_reg': 0.014250721124770624,
#  'colsample_bylevel': 0.061218122768953775,
#  'depth': 1,
#  'boosting_type': 'Plain',
#  'bootstrap_type': 'Bernoulli',
#  'min_data_in_leaf': 18,
#  'one_hot_max_size': 14,
#  'subsample': 0.9972814280760031}

# %% [markdown]
# ### Before we implement stacking, let's reserve a validation set for validation/testing the meta leaners's predictions before we make the submission because the test set that comes with compeition has no y.

# %%
X_train, X_valtest, y_train, y_valtest = train_test_split(X, y, shuffle=True, test_size=0.2, stratify=y)

# %%
# sanity check
len(X_train) == len(y_train)
# Out:
# True

# %% [markdown]
# # Stacking (finally!)

# %% [markdown]
# ### Let's set best parametes for each model here

# %%
# Tuned XGBoost Params
xgb_params = {'n_estimators': 272,
                 'max_depth': 4,
                 'learning_rate': 0.07360332417334109,
                 'min_child_weight': 1,
                 'gamma': 0.05180472121817407,
                 'subsample': 0.41981696676590474,
                 'colsample_bytree': 0.730818203141452,
                 'reg_alpha': 0.0005268315833160329,
                 'reg_lambda': 0.0007997627184403383}


# Tuned LightGBM Params
lgbm_params = {'n_estimators': 1942,
                 'num_rounds': 477,
                 'learning_rate': 0.2870761124159734,
                 'num_leaves': 37,
                 'max_depth': 6,
                 'min_data_in_leaf': 368,
                 'lambda_l1': 0.00017451291663562305,
                 'lambda_l2': 0.5090553595978456,
                 'min_gain_to_split': 0.02547126174774228,
                 'bagging_fraction': 0.20531850278394478,
                 'feature_fraction': 0.37437811030015083}


# Tuned Logistic Regression params
lr_params = {'solver': 'saga',
                 'C': 0.07655860626453208,
                 'tol': 0.00011268918749381429,
                 'max_iter': 484,
                 'penalty': 'l1',
                 'l1_ratio': 0.012007897837476486}


# Tuned CatBoost params
cat_params = {'loss_function': 'CrossEntropy',
                 'learning_rate': 0.7611165319863433,
                 'l2_leaf_reg': 0.014250721124770624,
                 'colsample_bylevel': 0.061218122768953775,
                 'depth': 1,
                 'boosting_type': 'Plain',
                 'bootstrap_type': 'Bernoulli',
                 'min_data_in_leaf': 18,
                 'one_hot_max_size': 14,
                 'subsample': 0.9972814280760031}

# %%
base_learners = []

xgb_model = xgb.XGBClassifier(**xgb_params)
base_learners.append(xgb_model)

lgbm_model = lgbm.LGBMClassifier(objective="binary", is_unbalance=True, **lgbm_params)
base_learners.append(lgbm_model)

cat_model = catboost.CatBoostClassifier(**cat_params)
base_learners.append(cat_model)

lr_model = LogisticRegression(**lr_params)
base_learners.append(lr_model)
