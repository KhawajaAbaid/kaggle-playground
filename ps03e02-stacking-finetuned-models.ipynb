# %% [markdown]
# # TODO:
# * Implement stacking (ensembling technique)
# * Use xgboost, catboost, lightgbm and keras and logistic regression as base models
# * Use linear regression with regularization (fine tune the regularization parameter with optuna) and tackle the task as regression with target values either being 0 or 1 and feature values of meta data being the probabilities predicted by our base models

# %%
import numpy as np
import pandas as pd
import os
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from pathlib import Path
import xgboost as xgb
import lightgbm as lgbm
import catboost
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.metrics import roc_auc_score
from sklearn.linear_model import LogisticRegression
from IPython.display import display
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
import optuna
from optuna.samplers import TPESampler
from optuna.integration import XGBoostPruningCallback
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %%
from warnings import filterwarnings
filterwarnings('ignore')

# %% [markdown]
# # Loading Data

# %%
BASE_DIR = Path("/kaggle/input/playground-series-s3e2/")

train = pd.read_csv(BASE_DIR / "train.csv").drop(columns="id")
test = pd.read_csv(BASE_DIR / "test.csv").drop(columns="id")

# %% [markdown]
# # Preprocessing

# %%
df = pd.concat([train.drop(columns=["stroke"]), test], axis=0).reset_index(drop=True)
df.head()
# Out:
#    gender   age  hypertension  heart_disease ever_married work_type  \
# 0    Male  28.0             0              0          Yes   Private
# 1    Male  33.0             0              0          Yes   Private
# 2  Female  42.0             0              0          Yes   Private
# 3    Male  56.0             0              0          Yes   Private
# 4  Female  24.0             0              0           No   Private
#
#   Residence_type  avg_glucose_level   bmi   smoking_status
# 0          Urban              79.53  31.1     never smoked
# 1          Rural              78.44  23.9  formerly smoked
# 2          Rural             103.00  40.3          Unknown
# 3          Urban              64.87  28.8     never smoked
# 4          Rural              73.36  28.8     never smoked

# %% [markdown]
# # Some feature engineering

# %%
def diabetes_indicator(avg_glucose_level):
    if avg_glucose_level <= 99:
        return "normal"
    elif avg_glucose_level >= 100 and avg_glucose_level <= 125:
        return "prediabetic"
    elif avg_glucose_level <= 200:
        return "type1"
    else:
        return "type2"

df.avg_glucose_level.map(diabetes_indicator).value_counts()
# Out:
# normal         20098
# prediabetic     4002
# type1            916
# type2            492
# Name: avg_glucose_level, dtype: int64

# %%
df["diabetes"] = df.avg_glucose_level.map(diabetes_indicator)
df.head(3)
# Out:
#    gender   age  hypertension  heart_disease ever_married work_type  \
# 0    Male  28.0             0              0          Yes   Private
# 1    Male  33.0             0              0          Yes   Private
# 2  Female  42.0             0              0          Yes   Private
#
#   Residence_type  avg_glucose_level   bmi   smoking_status     diabetes
# 0          Urban              79.53  31.1     never smoked       normal
# 1          Rural              78.44  23.9  formerly smoked       normal
# 2          Rural             103.00  40.3          Unknown  prediabetic

# %% [markdown]
# # Encoding - One hot

# %%
df = pd.get_dummies(df)
df.head(3)
# Out:
#     age  hypertension  heart_disease  avg_glucose_level   bmi  gender_Female  \
# 0  28.0             0              0              79.53  31.1              0
# 1  33.0             0              0              78.44  23.9              0
# 2  42.0             0              0             103.00  40.3              1
#
#    gender_Male  gender_Other  ever_married_No  ever_married_Yes  ...  \
# 0            1             0                0                 1  ...
# 1            1             0                0                 1  ...
# 2            0             0                0                 1  ...
#
#    Residence_type_Rural  Residence_type_Urban  smoking_status_Unknown  \
# 0                     0                     1                       0
# 1                     1                     0                       0
# 2                     1                     0                       1
#
#    smoking_status_formerly smoked  smoking_status_never smoked  \
# 0                               0                            1
# 1                               1                            0
# 2                               0                            0
#
#    smoking_status_smokes  diabetes_normal  diabetes_prediabetic  \
# 0                      0                1                     0
# 1                      0                1                     0
# 2                      0                0                     1
#
#    diabetes_type1  diabetes_type2
# 0               0               0
# 1               0               0
# 2               0               0
#
# [3 rows x 25 columns]

# %% [markdown]
# # Preprocessing v2

# %%
X = df.iloc[:-len(test), :]
test_new = df.iloc[-len(test):, :]
y = train.stroke

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Before we ensebmle, let's first finetune individual models and to get the optimized parameters for them

# %%
def cross_validate(X, y, model):
    kf = StratifiedKFold(n_splits=8, shuffle=True, random_state=1337)
    
    cv_scores = []
    
    for fold, (train_idx, val_idx) in enumerate(kf.split(X, y)):
        X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
        y_train, y_val = y.iloc[train_idx], y.iloc[val_idx]
                
        # training
        model.fit(X_train, y_train, verbose=0)

        # predicting
        y_pred = model.predict_proba(X_val)[:, 1]
        
        auc = roc_auc_score(y_val, y_pred)
        
        print(f"Fold: {fold} \t auc: {auc}")
        
        cv_scores.append(auc)
    
    avg_auc = np.mean(cv_scores)
    print(f"Avg AUC: {avg_auc}")

# %% [markdown]
# ## Finetuning Logsitic Regression

# %%
def objective(trial, X, y):
    params = {
        "solver": trial.suggest_categorical("solver", ["liblinear", "newton-cg", "saga", "lbfgs"]),
        "C": trial.suggest_loguniform("C", 0.01, 100.0),
        "tol": trial.suggest_loguniform("tol", 1e-6, 1e-2),
        "max_iter": trial.suggest_int("max_iter", 100, 1000),
    }
        
    if params["solver"] in ["newton-cg", "lbfgs"]:
        params["penalty"] = "l2"
        
    elif params["solver"] == "liblinear":
        params["penalty"] =  trial.suggest_categorical("penalty_liblinear", ["l1","l2"])
    
    elif params["solver"] == "saga":
        params["penalty"] =  trial.suggest_categorical("penalty_saga", ["l1","l2","elasticnet"])
        
        # saga also needs anothe parameter l1_ratio which ranges in 0-1
        params["l1_ratio"] = trial.suggest_loguniform("l1_ratio", 0.00001, 1)
        
        # saga also likes it's features to be scaled to converge so let's scale our data
        sc = StandardScaler()
        X = sc.fit_transform(X)
        
    # lets cross validate
    cv = StratifiedKFold(n_splits=8, shuffle=True, random_state=1337)
    
    cv_scores = []
    for fold, (train_idx, test_idx) in enumerate(cv.split(X, y)):
        # since we scale our dataset also, that converts it into a numpy ndarray
        # and hence it won't have iloc func that pandas dataframe has.
        # so let's check for the datatype of X first and then slice
        if type(X) == pd.core.frame.DataFrame:
            X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
            y_train, y_test = y[train_idx], y[test_idx]
        else:
            X_train, X_test = X[train_idx], X[test_idx]
            y_train, y_test = y[train_idx], y[test_idx]
            
        
        model = LogisticRegression(**params)       
        model.fit(X_train, y_train)
        
        y_pred = model.predict_proba(X_test)[:, 1]
        cv_scores.append(roc_auc_score(y_test, y_pred))
    
    auc = np.mean(cv_scores)
    return auc

# %%
lr_study = optuna.create_study(direction="maximize", study_name="linear regression tuning")
func = lambda trial: objective(trial, X, y)
lr_study.optimize(func, n_trials=100, show_progress_bar=True)

# %%
lr_study.best_value
# Out:
# 0.8842857487956048

# %%
lr_study.best_params
# Out:
# {'solver': 'saga',
#  'C': 0.05993945364272753,
#  'tol': 3.696312820565688e-05,
#  'max_iter': 694,
#  'penalty_saga': 'l1',
#  'l1_ratio': 0.20997642813431616}

# %% [markdown]
# ## Finetuning XGBoost

# %%
# we already have fintuned params for xgboost as following
xgb_params = {'n_estimators': 150,
                 'max_depth': 4,
                 'learning_rate': 0.10513333456836436,
                 'min_child_weight': 8,
                 'gamma': 0.002126415095687836,
                 'subsample': 0.5470092690254375,
                 'colsample_bytree': 0.6296509957360737,
                 'reg_alpha': 0.0003558325520757654,
                 'reg_lambda': 0.6330475930599759}

# %% [markdown]
# ## Finetuning LightGBM

# %%
from optuna.integration import LightGBMPruningCallback

def objective(trial, X, y):
    param_grid = {
#         "device_type": trial.suggest_categorical("device_type", ['gpu']),
        "is_unbalance": True,
        "n_estimators": trial.suggest_int("n_estimators", 100, 2000),
        "num_rounds": trial.suggest_int("num_rounds", 100, 500),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3),
        "num_leaves": trial.suggest_int("num_leaves", 20, 300),
        "max_depth": trial.suggest_int("max_depth", 2, 12),
        "min_data_in_leaf": trial.suggest_int("min_data_in_leaf", 20, 1000),
        "lambda_l1": trial.suggest_loguniform('lambda_l1', 0.00001, 1.0),
        "lambda_l2": trial.suggest_loguniform('lambda_l2', 0.00001, 1.0),
        "min_gain_to_split": trial.suggest_float("min_gain_to_split", 0, 15),
        "bagging_fraction":  trial.suggest_loguniform('bagging_fraction', 0.2, 1.0),
        "feature_fraction": trial.suggest_loguniform('feature_fraction', 0.2, 1.0),
    }

    cv = StratifiedKFold(n_splits=8, shuffle=True, random_state=1337)

    cv_scores = np.empty(8)
    for fold, (train_idx, test_idx) in enumerate(cv.split(X, y)):
        X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
        y_train, y_test = y[train_idx], y[test_idx]

        model = lgbm.LGBMClassifier(objective="binary", **param_grid)
        model.fit(
            X_train,
            y_train,
            eval_set=[(X_test, y_test)],
            eval_metric="auc",
            early_stopping_rounds=100,
            verbose=0,
            callbacks=[
                LightGBMPruningCallback(trial, "auc")
            ],  # Add a pruning callback
        )
        y_preds = model.predict_proba(X_test)[:, 1]
        cv_scores[fold] = roc_auc_score(y_test, y_preds)
    
    auc = np.mean(cv_scores)
    print(f"AVG CV AUC: \t {auc}")

    return auc

# %%
study = optuna.create_study(direction="maximize", study_name="LGBM Tuning")
func = lambda trial: objective(trial, X, y)
study.optimize(func, n_trials=100, show_progress_bar=True)

# %%
study.best_value
# Out:
# 0.8846192006128957

# %%
study.best_params
# Out:
# {'n_estimators': 1449,
#  'num_rounds': 150,
#  'learning_rate': 0.2487851433195791,
#  'num_leaves': 229,
#  'max_depth': 4,
#  'min_data_in_leaf': 903,
#  'lambda_l1': 1.6076796916985906e-05,
#  'lambda_l2': 0.0006193243147464635,
#  'min_gain_to_split': 5.754065628334817,
#  'bagging_fraction': 0.8222441421542225,
#  'feature_fraction': 0.9652642961816826}

# %%
lgbm_params = study.best_params

# %% [markdown]
# # CatBoost

# %%
def objective(trial, X, y):
    param = {
        "loss_function": trial.suggest_categorical("loss_function", ["CrossEntropy"]),
        "learning_rate": trial.suggest_loguniform("learning_rate", 1e-5, 1e0),
        "l2_leaf_reg": trial.suggest_loguniform("l2_leaf_reg", 1e-2, 1e0),
        "colsample_bylevel": trial.suggest_float("colsample_bylevel", 0.01, 0.1),
        "depth": trial.suggest_int("depth", 1, 10),
        "boosting_type": trial.suggest_categorical("boosting_type", ["Ordered", "Plain"]),
        "bootstrap_type": trial.suggest_categorical("bootstrap_type", ["Bayesian", "Bernoulli", "MVS"]),
        "min_data_in_leaf": trial.suggest_int("min_data_in_leaf", 2, 20),
        "one_hot_max_size": trial.suggest_int("one_hot_max_size", 2, 20),  
    }
    # Conditional Hyper-Parameters
    if param["bootstrap_type"] == "Bayesian":
        param["bagging_temperature"] = trial.suggest_float("bagging_temperature", 0, 10)
    elif param["bootstrap_type"] == "Bernoulli":
        param["subsample"] = trial.suggest_float("subsample", 0.1, 1)
    
    cv = StratifiedKFold(n_splits=8, shuffle=True, random_state=1337)

    cv_scores = np.empty(8)
    for fold, (train_idx, test_idx) in enumerate(cv.split(X, y)):
        X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
        y_train, y_test = y[train_idx], y[test_idx]

        cat_model = catboost.CatBoostClassifier(**param)
        cat_model.fit(X_train, y_train, eval_set=[(X_test, y_test)], verbose=0, early_stopping_rounds=100)
        
        y_preds = cat_model.predict_proba(X_test)[:, 1]
        cv_scores[fold] = roc_auc_score(y_test, y_preds)
    
    auc = np.mean(cv_scores)
    print(f"AVG CV AUC: \t {auc}")
    return auc

# %%
cat_study = optuna.create_study(direction="maximize", study_name="catboost tuning")
func = lambda trial: objective(trial, X, y)
cat_study.optimize(func, n_trials=100, show_progress_bar=True)
# Out:
# [I 2023-01-14 18:25:51,007] A new study created in memory with name: catboost tuning
#   0%|          | 0/100 [00:00<?, ?it/s]
# AVG CV AUC: 	 0.8348826836271275
# [I 2023-01-14 18:26:08,550] Trial 0 finished with value: 0.8348826836271275 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.0001660976380013114, 'l2_leaf_reg': 0.015245735436019528, 'colsample_bylevel': 0.018810974634979487, 'depth': 7, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 15, 'one_hot_max_size': 15, 'subsample': 0.8109421023773793}. Best is trial 0 with value: 0.8348826836271275.
# AVG CV AUC: 	 0.8755961583589857
# [I 2023-01-14 18:26:12,805] Trial 1 finished with value: 0.8755961583589857 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.3990474388394784, 'l2_leaf_reg': 0.29847285009274865, 'colsample_bylevel': 0.04570271539215538, 'depth': 7, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 15, 'one_hot_max_size': 4}. Best is trial 1 with value: 0.8755961583589857.
# AVG CV AUC: 	 0.8544372817249424
# [I 2023-01-14 18:26:36,956] Trial 2 finished with value: 0.8544372817249424 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.0003779405525777268, 'l2_leaf_reg': 0.1137407370831664, 'colsample_bylevel': 0.07890076944154957, 'depth': 5, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 10, 'one_hot_max_size': 8, 'subsample': 0.7287061939263068}. Best is trial 1 with value: 0.8755961583589857.
# AVG CV AUC: 	 0.8789940884557514
# [I 2023-01-14 18:26:44,228] Trial 3 finished with value: 0.8789940884557514 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.12370777954828237, 'l2_leaf_reg': 0.24048959817623175, 'colsample_bylevel': 0.058225912267906216, 'depth': 7, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 2, 'one_hot_max_size': 5}. Best is trial 3 with value: 0.8789940884557514.
# AVG CV AUC: 	 0.8828548824593129
# [I 2023-01-14 18:27:04,831] Trial 4 finished with value: 0.8828548824593129 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.1258006957808237, 'l2_leaf_reg': 0.049762440555528566, 'colsample_bylevel': 0.09998418287445995, 'depth': 6, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 17, 'one_hot_max_size': 17, 'subsample': 0.8508222071342286}. Best is trial 4 with value: 0.8828548824593129.
# AVG CV AUC: 	 0.8574879560482034
# [I 2023-01-14 18:28:12,672] Trial 5 finished with value: 0.8574879560482034 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.0007061348427943915, 'l2_leaf_reg': 0.1416090421935413, 'colsample_bylevel': 0.08520978516589463, 'depth': 1, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 15, 'one_hot_max_size': 14}. Best is trial 4 with value: 0.8828548824593129.
# AVG CV AUC: 	 0.8514077447096338
# [I 2023-01-14 18:28:30,850] Trial 6 finished with value: 0.8514077447096338 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.0009618816540459264, 'l2_leaf_reg': 0.228199661178712, 'colsample_bylevel': 0.05424765367310427, 'depth': 3, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 2, 'one_hot_max_size': 13, 'subsample': 0.18555546599796166}. Best is trial 4 with value: 0.8828548824593129.
# AVG CV AUC: 	 0.8274984297999807
# [I 2023-01-14 18:28:47,740] Trial 7 finished with value: 0.8274984297999807 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.00010798337724158786, 'l2_leaf_reg': 0.06576835454406497, 'colsample_bylevel': 0.015077441752521532, 'depth': 1, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'min_data_in_leaf': 13, 'one_hot_max_size': 2, 'bagging_temperature': 3.4731912334847426}. Best is trial 4 with value: 0.8828548824593129.
# AVG CV AUC: 	 0.8475913821901357
# [I 2023-01-14 18:30:20,149] Trial 8 finished with value: 0.8475913821901357 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 3.558555212122194e-05, 'l2_leaf_reg': 0.9553771684172163, 'colsample_bylevel': 0.07920495112002142, 'depth': 5, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 11, 'one_hot_max_size': 13}. Best is trial 4 with value: 0.8828548824593129.
# AVG CV AUC: 	 0.8555079510787792
# [I 2023-01-14 18:30:52,059] Trial 9 finished with value: 0.8555079510787792 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.0003979517784365725, 'l2_leaf_reg': 0.8441767931165606, 'colsample_bylevel': 0.06489798598850256, 'depth': 9, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 6, 'one_hot_max_size': 20}. Best is trial 4 with value: 0.8828548824593129.
# AVG CV AUC: 	 0.8653467208702015
# [I 2023-01-14 18:32:26,637] Trial 10 finished with value: 0.8653467208702015 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.020177146304555683, 'l2_leaf_reg': 0.0310641287090899, 'colsample_bylevel': 0.09873165603771741, 'depth': 10, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'min_data_in_leaf': 19, 'one_hot_max_size': 20, 'bagging_temperature': 9.66442727359378}. Best is trial 4 with value: 0.8828548824593129.
# AVG CV AUC: 	 0.879277500931767
# [I 2023-01-14 18:32:59,741] Trial 11 finished with value: 0.879277500931767 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.11369876101189515, 'l2_leaf_reg': 0.04634581291837065, 'colsample_bylevel': 0.03355692944394993, 'depth': 7, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 20, 'one_hot_max_size': 8, 'subsample': 0.9687062598817444}. Best is trial 4 with value: 0.8828548824593129.
# AVG CV AUC: 	 0.8521604916969203
# [I 2023-01-14 18:34:03,502] Trial 12 finished with value: 0.8521604916969203 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.011636758049076197, 'l2_leaf_reg': 0.04253273397708505, 'colsample_bylevel': 0.03239142219286431, 'depth': 8, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 20, 'one_hot_max_size': 9, 'subsample': 0.9906430995527258}. Best is trial 4 with value: 0.8828548824593129.
# AVG CV AUC: 	 0.8809978189749181
# [I 2023-01-14 18:34:14,550] Trial 13 finished with value: 0.8809978189749181 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.8079651307310215, 'l2_leaf_reg': 0.011503165502351802, 'colsample_bylevel': 0.0359690430120896, 'depth': 4, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 19, 'one_hot_max_size': 17, 'subsample': 0.9774062925497601}. Best is trial 4 with value: 0.8828548824593129.
# AVG CV AUC: 	 0.8735173688279061
# [I 2023-01-14 18:34:25,144] Trial 14 finished with value: 0.8735173688279061 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.9960762099141597, 'l2_leaf_reg': 0.013203215697356871, 'colsample_bylevel': 0.03929629437363389, 'depth': 3, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 17, 'one_hot_max_size': 18, 'subsample': 0.5056641567130946}. Best is trial 4 with value: 0.8828548824593129.
# AVG CV AUC: 	 0.885167045125133
# [I 2023-01-14 18:35:04,527] Trial 15 finished with value: 0.885167045125133 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.04964408090824197, 'l2_leaf_reg': 0.02438874969121421, 'colsample_bylevel': 0.09581410368512243, 'depth': 4, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 17, 'one_hot_max_size': 17, 'subsample': 0.6952891606346389}. Best is trial 15 with value: 0.885167045125133.
# AVG CV AUC: 	 0.8847740637466698
# [I 2023-01-14 18:36:13,981] Trial 16 finished with value: 0.8847740637466698 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.020201964774352144, 'l2_leaf_reg': 0.02364039368964462, 'colsample_bylevel': 0.0999426164916094, 'depth': 3, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 8, 'one_hot_max_size': 17, 'subsample': 0.606728581017874}. Best is trial 15 with value: 0.885167045125133.
# AVG CV AUC: 	 0.8827642939966593
# [I 2023-01-14 18:37:29,087] Trial 17 finished with value: 0.8827642939966593 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.01490549870533921, 'l2_leaf_reg': 0.02615060646796325, 'colsample_bylevel': 0.09132833474190308, 'depth': 3, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'min_data_in_leaf': 8, 'one_hot_max_size': 11, 'bagging_temperature': 0.06410556986961868}. Best is trial 15 with value: 0.885167045125133.
# AVG CV AUC: 	 0.8578904276465635
# [I 2023-01-14 18:38:35,183] Trial 18 finished with value: 0.8578904276465635 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.0035757108294806835, 'l2_leaf_reg': 0.01953509092339316, 'colsample_bylevel': 0.07629821703763054, 'depth': 2, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 5, 'one_hot_max_size': 16, 'subsample': 0.5458620263808125}. Best is trial 15 with value: 0.885167045125133.
# AVG CV AUC: 	 0.8640129136010382
# [I 2023-01-14 18:39:52,774] Trial 19 finished with value: 0.8640129136010382 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.0030999273300065943, 'l2_leaf_reg': 0.07359988801518308, 'colsample_bylevel': 0.0878908926291334, 'depth': 4, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 9, 'one_hot_max_size': 19, 'subsample': 0.38243963611557885}. Best is trial 15 with value: 0.885167045125133.
# AVG CV AUC: 	 0.877526986734398
# [I 2023-01-14 18:40:57,216] Trial 20 finished with value: 0.877526986734398 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.030557863222298653, 'l2_leaf_reg': 0.0235859376319103, 'colsample_bylevel': 0.07162075892580282, 'depth': 2, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'min_data_in_leaf': 13, 'one_hot_max_size': 12, 'bagging_temperature': 9.823136406971086}. Best is trial 15 with value: 0.885167045125133.
# AVG CV AUC: 	 0.878981147246801
# [I 2023-01-14 18:41:24,564] Trial 21 finished with value: 0.878981147246801 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.06867262804913449, 'l2_leaf_reg': 0.041997374283881436, 'colsample_bylevel': 0.09903998904042821, 'depth': 6, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 17, 'one_hot_max_size': 17, 'subsample': 0.7157977445417368}. Best is trial 15 with value: 0.885167045125133.
# AVG CV AUC: 	 0.8813705257926923
# [I 2023-01-14 18:41:40,971] Trial 22 finished with value: 0.8813705257926923 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.2920333834204527, 'l2_leaf_reg': 0.06426648266318274, 'colsample_bylevel': 0.0924165968567039, 'depth': 4, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 12, 'one_hot_max_size': 16, 'subsample': 0.6804202192265625}. Best is trial 15 with value: 0.885167045125133.
# AVG CV AUC: 	 0.8741079193296799
# [I 2023-01-14 18:43:19,985] Trial 23 finished with value: 0.8741079193296799 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.004372197065383664, 'l2_leaf_reg': 0.032628124838307446, 'colsample_bylevel': 0.09997046986729434, 'depth': 6, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 7, 'one_hot_max_size': 18, 'subsample': 0.8479803806248578}. Best is trial 15 with value: 0.885167045125133.
# AVG CV AUC: 	 0.8821198217909253
# [I 2023-01-14 18:43:49,256] Trial 24 finished with value: 0.8821198217909253 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.053538049420242345, 'l2_leaf_reg': 0.018540881182028034, 'colsample_bylevel': 0.08557463443539892, 'depth': 5, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 17, 'one_hot_max_size': 15, 'subsample': 0.6204210983986875}. Best is trial 15 with value: 0.885167045125133.
# AVG CV AUC: 	 0.8775662417348813
# [I 2023-01-14 18:44:03,241] Trial 25 finished with value: 0.8775662417348813 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.2132637614246127, 'l2_leaf_reg': 0.010530249560136694, 'colsample_bylevel': 0.09300113040714254, 'depth': 4, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 14, 'one_hot_max_size': 11, 'subsample': 0.4657235900251195}. Best is trial 15 with value: 0.885167045125133.
# AVG CV AUC: 	 0.8851178685311211
# [I 2023-01-14 18:44:58,296] Trial 26 finished with value: 0.8851178685311211 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.05005082654102864, 'l2_leaf_reg': 0.08164012564637917, 'colsample_bylevel': 0.06850903028033135, 'depth': 2, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 18, 'one_hot_max_size': 18, 'subsample': 0.8112384402615178}. Best is trial 15 with value: 0.885167045125133.
# AVG CV AUC: 	 0.8604122378973813
# [I 2023-01-14 18:46:04,694] Trial 27 finished with value: 0.8604122378973813 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.00889668559701344, 'l2_leaf_reg': 0.15636097964217036, 'colsample_bylevel': 0.06419860346550951, 'depth': 2, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 4, 'one_hot_max_size': 19, 'subsample': 0.6242614724803303}. Best is trial 15 with value: 0.885167045125133.
# AVG CV AUC: 	 0.8845678671507254
# [I 2023-01-14 18:47:00,652] Trial 28 finished with value: 0.8845678671507254 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.043655842194919706, 'l2_leaf_reg': 0.018486495034022492, 'colsample_bylevel': 0.07266825271491863, 'depth': 3, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 10, 'one_hot_max_size': 15, 'subsample': 0.37079151528833343}. Best is trial 15 with value: 0.885167045125133.
# AVG CV AUC: 	 0.8587833710641469
# [I 2023-01-14 18:48:01,060] Trial 29 finished with value: 0.8587833710641469 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.007542656997733678, 'l2_leaf_reg': 0.08938140782577265, 'colsample_bylevel': 0.08249315362364627, 'depth': 1, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'min_data_in_leaf': 16, 'one_hot_max_size': 15, 'bagging_temperature': 5.717845882426445}. Best is trial 15 with value: 0.885167045125133.
# AVG CV AUC: 	 0.8404396387504659
# [I 2023-01-14 18:49:02,439] Trial 30 finished with value: 0.8404396387504659 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.0016101846269856025, 'l2_leaf_reg': 0.014589429547363083, 'colsample_bylevel': 0.021065277622485792, 'depth': 2, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 18, 'one_hot_max_size': 19, 'subsample': 0.7677435878599123}. Best is trial 15 with value: 0.885167045125133.
# AVG CV AUC: 	 0.8842033564319534
# [I 2023-01-14 18:50:03,460] Trial 31 finished with value: 0.8842033564319534 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.032765951259603035, 'l2_leaf_reg': 0.019109326941366245, 'colsample_bylevel': 0.07139968718980994, 'depth': 3, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 10, 'one_hot_max_size': 14, 'subsample': 0.3475480196159234}. Best is trial 15 with value: 0.885167045125133.
# AVG CV AUC: 	 0.884255552641387
# [I 2023-01-14 18:50:59,787] Trial 32 finished with value: 0.884255552641387 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.051273002635749736, 'l2_leaf_reg': 0.03373414900610216, 'colsample_bylevel': 0.04913891339178336, 'depth': 3, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 8, 'one_hot_max_size': 16, 'subsample': 0.23568910761355621}. Best is trial 15 with value: 0.885167045125133.
# AVG CV AUC: 	 0.8838798262081913
# [I 2023-01-14 18:52:02,297] Trial 33 finished with value: 0.8838798262081913 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.02699118383325269, 'l2_leaf_reg': 0.3564497804717024, 'colsample_bylevel': 0.0702970710805313, 'depth': 2, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 11, 'one_hot_max_size': 18, 'subsample': 0.612281790390307}. Best is trial 15 with value: 0.885167045125133.
# AVG CV AUC: 	 0.8800716597876952
# [I 2023-01-14 18:52:11,179] Trial 34 finished with value: 0.8800716597876952 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.08042367674496505, 'l2_leaf_reg': 0.02365022207067657, 'colsample_bylevel': 0.06169095811422299, 'depth': 4, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 9, 'one_hot_max_size': 14, 'subsample': 0.4042315013588712}. Best is trial 15 with value: 0.885167045125133.
# AVG CV AUC: 	 0.8797110314316083
# [I 2023-01-14 18:52:24,240] Trial 35 finished with value: 0.8797110314316083 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.22946638901719776, 'l2_leaf_reg': 0.016639299333338815, 'colsample_bylevel': 0.07787469559341446, 'depth': 5, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 15, 'one_hot_max_size': 16}. Best is trial 15 with value: 0.885167045125133.
# AVG CV AUC: 	 0.8787136955951576
# [I 2023-01-14 18:52:28,829] Trial 36 finished with value: 0.8787136955951576 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.43298396270098516, 'l2_leaf_reg': 0.12004804761586965, 'colsample_bylevel': 0.0549574114275046, 'depth': 3, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 12, 'one_hot_max_size': 17, 'subsample': 0.2716223711283521}. Best is trial 15 with value: 0.885167045125133.
# AVG CV AUC: 	 0.8561640703725688
# [I 2023-01-14 18:53:30,476] Trial 37 finished with value: 0.8561640703725688 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.007128497468962988, 'l2_leaf_reg': 0.4004661393866242, 'colsample_bylevel': 0.09303560054280377, 'depth': 1, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 10, 'one_hot_max_size': 20, 'subsample': 0.8823084744646121}. Best is trial 15 with value: 0.885167045125133.
# AVG CV AUC: 	 0.8874468547685768
# [I 2023-01-14 18:53:41,788] Trial 38 finished with value: 0.8874468547685768 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.16458476988243417, 'l2_leaf_reg': 0.051663614456296074, 'colsample_bylevel': 0.047088058423033416, 'depth': 2, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 14, 'one_hot_max_size': 5}. Best is trial 38 with value: 0.8874468547685768.
# AVG CV AUC: 	 0.8370136693676408
# [I 2023-01-14 18:54:03,499] Trial 39 finished with value: 0.8370136693676408 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 1.0926447109604625e-05, 'l2_leaf_reg': 0.05640848497422439, 'colsample_bylevel': 0.04599909094207471, 'depth': 2, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 16, 'one_hot_max_size': 6}. Best is trial 38 with value: 0.8874468547685768.
# AVG CV AUC: 	 0.8879243853788495
# [I 2023-01-14 18:54:20,243] Trial 40 finished with value: 0.8879243853788495 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.15884407059008493, 'l2_leaf_reg': 0.08507297641885786, 'colsample_bylevel': 0.050615825967468435, 'depth': 1, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 14, 'one_hot_max_size': 3}. Best is trial 40 with value: 0.8879243853788495.
# AVG CV AUC: 	 0.8853676338638654
# [I 2023-01-14 18:54:37,351] Trial 41 finished with value: 0.8853676338638654 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.12047762716993589, 'l2_leaf_reg': 0.09463703162765923, 'colsample_bylevel': 0.042166886507280885, 'depth': 1, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 14, 'one_hot_max_size': 2}. Best is trial 40 with value: 0.8879243853788495.
# AVG CV AUC: 	 0.8869727751473572
# [I 2023-01-14 18:54:53,381] Trial 42 finished with value: 0.8869727751473572 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.1310187722115461, 'l2_leaf_reg': 0.08881134070645912, 'colsample_bylevel': 0.04164237013640816, 'depth': 1, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 14, 'one_hot_max_size': 3}. Best is trial 40 with value: 0.8879243853788495.
# AVG CV AUC: 	 0.8890998785251853
# [I 2023-01-14 18:55:02,621] Trial 43 finished with value: 0.8890998785251853 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.4903612056249371, 'l2_leaf_reg': 0.10469096046936131, 'colsample_bylevel': 0.026865789009700554, 'depth': 1, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 14, 'one_hot_max_size': 2}. Best is trial 43 with value: 0.8890998785251853.
# AVG CV AUC: 	 0.8873433250969728
# [I 2023-01-14 18:55:12,930] Trial 44 finished with value: 0.8873433250969728 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.44831984366574856, 'l2_leaf_reg': 0.10970813044543994, 'colsample_bylevel': 0.02459102754671349, 'depth': 1, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 14, 'one_hot_max_size': 2}. Best is trial 43 with value: 0.8890998785251853.
# AVG CV AUC: 	 0.8877544241679665
# [I 2023-01-14 18:55:22,481] Trial 45 finished with value: 0.8877544241679665 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.5574359370241333, 'l2_leaf_reg': 0.16908917546613825, 'colsample_bylevel': 0.026839208746698828, 'depth': 1, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 14, 'one_hot_max_size': 4}. Best is trial 43 with value: 0.8890998785251853.
# AVG CV AUC: 	 0.8875188941650677
# [I 2023-01-14 18:55:30,506] Trial 46 finished with value: 0.8875188941650677 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.7480988870243437, 'l2_leaf_reg': 0.19631498793439253, 'colsample_bylevel': 0.02647283818780611, 'depth': 1, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 13, 'one_hot_max_size': 5}. Best is trial 43 with value: 0.8890998785251853.
# AVG CV AUC: 	 0.8708777935756388
# [I 2023-01-14 18:55:39,043] Trial 47 finished with value: 0.8708777935756388 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.6599121683310153, 'l2_leaf_reg': 0.1763175248951491, 'colsample_bylevel': 0.011256576255274523, 'depth': 1, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 13, 'one_hot_max_size': 5}. Best is trial 43 with value: 0.8890998785251853.
# AVG CV AUC: 	 0.8871474814681888
# [I 2023-01-14 18:55:49,249] Trial 48 finished with value: 0.8871474814681888 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.5212770920827547, 'l2_leaf_reg': 0.20781137042395262, 'colsample_bylevel': 0.029802904768915034, 'depth': 1, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 12, 'one_hot_max_size': 4}. Best is trial 43 with value: 0.8890998785251853.
# AVG CV AUC: 	 0.8878389733997764
# [I 2023-01-14 18:56:03,315] Trial 49 finished with value: 0.8878389733997764 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.2902540314683066, 'l2_leaf_reg': 0.2833369275744832, 'colsample_bylevel': 0.026844068350933052, 'depth': 1, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 16, 'one_hot_max_size': 7}. Best is trial 43 with value: 0.8890998785251853.
# AVG CV AUC: 	 0.8864374404704388
# [I 2023-01-14 18:56:15,861] Trial 50 finished with value: 0.8864374404704388 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.3041290691688204, 'l2_leaf_reg': 0.2979432247518649, 'colsample_bylevel': 0.025097681683789716, 'depth': 1, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 16, 'one_hot_max_size': 7}. Best is trial 43 with value: 0.8890998785251853.
# AVG CV AUC: 	 0.878930676531894
# [I 2023-01-14 18:56:27,951] Trial 51 finished with value: 0.878930676531894 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.20260142720040267, 'l2_leaf_reg': 0.6109537932836243, 'colsample_bylevel': 0.018849088847589648, 'depth': 2, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 15, 'one_hot_max_size': 4}. Best is trial 43 with value: 0.8890998785251853.
# AVG CV AUC: 	 0.8866427743191199
# [I 2023-01-14 18:56:35,353] Trial 52 finished with value: 0.8866427743191199 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.8835033236033075, 'l2_leaf_reg': 0.14144473330341628, 'colsample_bylevel': 0.02873394922044244, 'depth': 1, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 13, 'one_hot_max_size': 5}. Best is trial 43 with value: 0.8890998785251853.
# AVG CV AUC: 	 0.8872212463592066
# [I 2023-01-14 18:56:50,599] Trial 53 finished with value: 0.8872212463592066 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.1564948567707557, 'l2_leaf_reg': 0.2686172194727383, 'colsample_bylevel': 0.03739741742965558, 'depth': 1, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 15, 'one_hot_max_size': 3}. Best is trial 43 with value: 0.8890998785251853.
# AVG CV AUC: 	 0.8823855479480418
# [I 2023-01-14 18:57:02,505] Trial 54 finished with value: 0.8823855479480418 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.32799881980087014, 'l2_leaf_reg': 0.204745382455884, 'colsample_bylevel': 0.015096989295733958, 'depth': 2, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 13, 'one_hot_max_size': 3}. Best is trial 43 with value: 0.8890998785251853.
# AVG CV AUC: 	 0.8866595978907554
# [I 2023-01-14 18:57:11,260] Trial 55 finished with value: 0.8866595978907554 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.6610405316095954, 'l2_leaf_reg': 0.12787496033077136, 'colsample_bylevel': 0.033281807929242936, 'depth': 1, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 12, 'one_hot_max_size': 6}. Best is trial 43 with value: 0.8890998785251853.
# AVG CV AUC: 	 0.8877078358157449
# [I 2023-01-14 18:57:27,891] Trial 56 finished with value: 0.8877078358157449 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.08928836080902253, 'l2_leaf_reg': 0.4455228553216033, 'colsample_bylevel': 0.04971209986825103, 'depth': 2, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 16, 'one_hot_max_size': 9}. Best is trial 43 with value: 0.8890998785251853.
# AVG CV AUC: 	 0.8733047016274864
# [I 2023-01-14 18:57:31,738] Trial 57 finished with value: 0.8733047016274864 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.5039339919179167, 'l2_leaf_reg': 0.44743068154155236, 'colsample_bylevel': 0.05192461127062563, 'depth': 8, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 16, 'one_hot_max_size': 9}. Best is trial 43 with value: 0.8890998785251853.
# AVG CV AUC: 	 0.8878665813122041
# [I 2023-01-14 18:57:39,251] Trial 58 finished with value: 0.8878665813122041 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.9308298316375059, 'l2_leaf_reg': 0.1740698882906466, 'colsample_bylevel': 0.05860415920527992, 'depth': 1, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 18, 'one_hot_max_size': 8}. Best is trial 43 with value: 0.8890998785251853.
# AVG CV AUC: 	 0.8869343828941375
# [I 2023-01-14 18:57:52,239] Trial 59 finished with value: 0.8869343828941375 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.10228701438020395, 'l2_leaf_reg': 0.582101348056777, 'colsample_bylevel': 0.05777689543034319, 'depth': 2, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 19, 'one_hot_max_size': 9}. Best is trial 43 with value: 0.8890998785251853.
# AVG CV AUC: 	 0.8853141435335368
# [I 2023-01-14 18:57:58,683] Trial 60 finished with value: 0.8853141435335368 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.3018500693693298, 'l2_leaf_reg': 0.3278580036346349, 'colsample_bylevel': 0.059140290316634765, 'depth': 2, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 18, 'one_hot_max_size': 8}. Best is trial 43 with value: 0.8890998785251853.
# AVG CV AUC: 	 0.8848361815496322
# [I 2023-01-14 18:58:04,624] Trial 61 finished with value: 0.8848361815496322 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.8891305239105466, 'l2_leaf_reg': 0.1734345846761137, 'colsample_bylevel': 0.023816277729343287, 'depth': 1, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 15, 'one_hot_max_size': 7}. Best is trial 43 with value: 0.8890998785251853.
# AVG CV AUC: 	 0.8870072850378918
# [I 2023-01-14 18:58:10,335] Trial 62 finished with value: 0.8870072850378918 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.9893776964113022, 'l2_leaf_reg': 0.25260297357874123, 'colsample_bylevel': 0.028483895675807447, 'depth': 1, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 16, 'one_hot_max_size': 4}. Best is trial 43 with value: 0.8890998785251853.
# AVG CV AUC: 	 0.8894307421006861
# [I 2023-01-14 18:58:19,001] Trial 63 finished with value: 0.8894307421006861 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.5642073841955543, 'l2_leaf_reg': 0.20722296381133357, 'colsample_bylevel': 0.05080456061345507, 'depth': 1, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 17, 'one_hot_max_size': 10}. Best is trial 63 with value: 0.8894307421006861.
# AVG CV AUC: 	 0.8892374867136923
# [I 2023-01-14 18:58:28,472] Trial 64 finished with value: 0.8892374867136923 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.3975510513736826, 'l2_leaf_reg': 0.14336287344106638, 'colsample_bylevel': 0.052868569113116326, 'depth': 1, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 20, 'one_hot_max_size': 9}. Best is trial 63 with value: 0.8894307421006861.
# AVG CV AUC: 	 0.8888889368192925
# [I 2023-01-14 18:58:39,896] Trial 65 finished with value: 0.8888889368192925 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.3909692118266333, 'l2_leaf_reg': 0.15232870613244923, 'colsample_bylevel': 0.042745585271628334, 'depth': 1, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 20, 'one_hot_max_size': 10}. Best is trial 63 with value: 0.8894307421006861.
# AVG CV AUC: 	 0.8888729759949201
# [I 2023-01-14 18:58:47,475] Trial 66 finished with value: 0.8888729759949201 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.3631083017131325, 'l2_leaf_reg': 0.10949946482513422, 'colsample_bylevel': 0.0520628717253166, 'depth': 1, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'min_data_in_leaf': 20, 'one_hot_max_size': 10, 'bagging_temperature': 0.18831694537465626}. Best is trial 63 with value: 0.8894307421006861.
# AVG CV AUC: 	 0.8497620543047637
# [I 2023-01-14 18:59:12,051] Trial 67 finished with value: 0.8497620543047637 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.0002169561027315794, 'l2_leaf_reg': 0.10462301839583625, 'colsample_bylevel': 0.052927875310104275, 'depth': 10, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'min_data_in_leaf': 20, 'one_hot_max_size': 10, 'bagging_temperature': 0.18656099952528393}. Best is trial 63 with value: 0.8894307421006861.
# AVG CV AUC: 	 0.8802601700647406
# [I 2023-01-14 18:59:17,261] Trial 68 finished with value: 0.8802601700647406 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.398560434695756, 'l2_leaf_reg': 0.13616173629985476, 'colsample_bylevel': 0.05742062087133507, 'depth': 2, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'min_data_in_leaf': 20, 'one_hot_max_size': 12, 'bagging_temperature': 3.0161044743702403}. Best is trial 63 with value: 0.8894307421006861.
# AVG CV AUC: 	 0.8701970859848432
# [I 2023-01-14 18:59:28,510] Trial 69 finished with value: 0.8701970859848432 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.2033382756837414, 'l2_leaf_reg': 0.0728533105126001, 'colsample_bylevel': 0.04316009290566604, 'depth': 1, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'min_data_in_leaf': 19, 'one_hot_max_size': 10, 'bagging_temperature': 6.750032021177691}. Best is trial 63 with value: 0.8894307421006861.
# AVG CV AUC: 	 0.8846597497342739
# [I 2023-01-14 18:59:33,720] Trial 70 finished with value: 0.8846597497342739 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.37600682248710743, 'l2_leaf_reg': 0.2294537896545212, 'colsample_bylevel': 0.0647637110111768, 'depth': 2, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'min_data_in_leaf': 18, 'one_hot_max_size': 10, 'bagging_temperature': 2.2697055951150165}. Best is trial 63 with value: 0.8894307421006861.
# AVG CV AUC: 	 0.8881405035683227
# [I 2023-01-14 18:59:44,869] Trial 71 finished with value: 0.8881405035683227 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.25622530411843375, 'l2_leaf_reg': 0.1459922445053459, 'colsample_bylevel': 0.05097800785307033, 'depth': 1, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 19, 'one_hot_max_size': 8}. Best is trial 63 with value: 0.8894307421006861.
# AVG CV AUC: 	 0.8878898754883149
# [I 2023-01-14 18:59:51,939] Trial 72 finished with value: 0.8878898754883149 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.6352626699704159, 'l2_leaf_reg': 0.11564379446931004, 'colsample_bylevel': 0.05183183387345119, 'depth': 1, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 19, 'one_hot_max_size': 12}. Best is trial 63 with value: 0.8894307421006861.
# AVG CV AUC: 	 0.8878803852684178
# [I 2023-01-14 19:00:05,949] Trial 73 finished with value: 0.8878803852684178 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.2577010986412174, 'l2_leaf_reg': 0.11960357919292047, 'colsample_bylevel': 0.05018698346263948, 'depth': 1, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 19, 'one_hot_max_size': 12}. Best is trial 63 with value: 0.8894307421006861.
# AVG CV AUC: 	 0.8838509241748684
# [I 2023-01-14 19:00:13,241] Trial 74 finished with value: 0.8838509241748684 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.5564238520630493, 'l2_leaf_reg': 0.1517038831675532, 'colsample_bylevel': 0.04715871517946557, 'depth': 1, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'min_data_in_leaf': 20, 'one_hot_max_size': 11, 'bagging_temperature': 1.6206425292092692}. Best is trial 63 with value: 0.8894307421006861.
# AVG CV AUC: 	 0.8874278743287827
# [I 2023-01-14 19:00:24,345] Trial 75 finished with value: 0.8874278743287827 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.1661578942607228, 'l2_leaf_reg': 0.08182444653281117, 'colsample_bylevel': 0.044319927918336985, 'depth': 2, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 19, 'one_hot_max_size': 13}. Best is trial 63 with value: 0.8894307421006861.
# AVG CV AUC: 	 0.8887672894551578
# [I 2023-01-14 19:00:34,874] Trial 76 finished with value: 0.8887672894551578 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.3959390544501711, 'l2_leaf_reg': 0.1029967514293815, 'colsample_bylevel': 0.03952929195655368, 'depth': 1, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 20, 'one_hot_max_size': 10}. Best is trial 63 with value: 0.8894307421006861.
# AVG CV AUC: 	 0.8857278308463206
# [I 2023-01-14 19:00:54,588] Trial 77 finished with value: 0.8857278308463206 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.06827598426819324, 'l2_leaf_reg': 0.06321407802217319, 'colsample_bylevel': 0.03933652367001029, 'depth': 3, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 20, 'one_hot_max_size': 10}. Best is trial 63 with value: 0.8894307421006861.
# AVG CV AUC: 	 0.8758273746255677
# [I 2023-01-14 19:01:06,272] Trial 78 finished with value: 0.8758273746255677 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.21104102328701602, 'l2_leaf_reg': 0.07496450876729711, 'colsample_bylevel': 0.05546418684622195, 'depth': 2, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'min_data_in_leaf': 20, 'one_hot_max_size': 11, 'bagging_temperature': 7.480152132035859}. Best is trial 63 with value: 0.8894307421006861.
# AVG CV AUC: 	 0.8884994064298828
# [I 2023-01-14 19:01:18,217] Trial 79 finished with value: 0.8884994064298828 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.36051533985044865, 'l2_leaf_reg': 0.09600224525515143, 'colsample_bylevel': 0.03999475368840547, 'depth': 1, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 18, 'one_hot_max_size': 10}. Best is trial 63 with value: 0.8894307421006861.
# AVG CV AUC: 	 0.8884558376930829
# [I 2023-01-14 19:01:29,814] Trial 80 finished with value: 0.8884558376930829 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.4723529309649959, 'l2_leaf_reg': 0.10178358499897808, 'colsample_bylevel': 0.035498418187626876, 'depth': 1, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 17, 'one_hot_max_size': 11}. Best is trial 63 with value: 0.8894307421006861.
# AVG CV AUC: 	 0.8891197217122427
# [I 2023-01-14 19:01:43,635] Trial 81 finished with value: 0.8891197217122427 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.37973977141574505, 'l2_leaf_reg': 0.10520703764665408, 'colsample_bylevel': 0.03532462126239874, 'depth': 1, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 17, 'one_hot_max_size': 9}. Best is trial 63 with value: 0.8894307421006861.
# AVG CV AUC: 	 0.8883579158786908
# [I 2023-01-14 19:01:53,596] Trial 82 finished with value: 0.8883579158786908 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.4473080685248286, 'l2_leaf_reg': 0.09542353669269804, 'colsample_bylevel': 0.037910741482361135, 'depth': 1, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 17, 'one_hot_max_size': 11}. Best is trial 63 with value: 0.8894307421006861.
# AVG CV AUC: 	 0.8850911233659566
# [I 2023-01-14 19:02:01,227] Trial 83 finished with value: 0.8850911233659566 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.3661722256020231, 'l2_leaf_reg': 0.09996629759679407, 'colsample_bylevel': 0.03460475708878599, 'depth': 2, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 17, 'one_hot_max_size': 10}. Best is trial 63 with value: 0.8894307421006861.
# AVG CV AUC: 	 0.8879670913683861
# [I 2023-01-14 19:02:09,810] Trial 84 finished with value: 0.8879670913683861 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.6160569285385978, 'l2_leaf_reg': 0.12839553144096003, 'colsample_bylevel': 0.04090979079110615, 'depth': 1, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 18, 'one_hot_max_size': 9}. Best is trial 63 with value: 0.8894307421006861.
# AVG CV AUC: 	 0.8887983483566391
# [I 2023-01-14 19:02:20,053] Trial 85 finished with value: 0.8887983483566391 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.4025458950011765, 'l2_leaf_reg': 0.11319835423512399, 'colsample_bylevel': 0.0317406591373622, 'depth': 1, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 17, 'one_hot_max_size': 13}. Best is trial 63 with value: 0.8894307421006861.
# AVG CV AUC: 	 0.8809809954032826
# [I 2023-01-14 19:02:29,366] Trial 86 finished with value: 0.8809809954032826 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.13623931403487002, 'l2_leaf_reg': 0.07109367579320129, 'colsample_bylevel': 0.03199676700536813, 'depth': 9, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 20, 'one_hot_max_size': 10}. Best is trial 63 with value: 0.8894307421006861.
# AVG CV AUC: 	 0.8772599664563864
# [I 2023-01-14 19:02:33,762] Trial 87 finished with value: 0.8772599664563864 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.34595267317380635, 'l2_leaf_reg': 0.05871352074883005, 'colsample_bylevel': 0.04791052558219245, 'depth': 7, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 18, 'one_hot_max_size': 13}. Best is trial 63 with value: 0.8894307421006861.
# AVG CV AUC: 	 0.8594209412917742
# [I 2023-01-14 19:02:39,370] Trial 88 finished with value: 0.8594209412917742 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.736999536658361, 'l2_leaf_reg': 0.15843476348110636, 'colsample_bylevel': 0.03080082150341333, 'depth': 2, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'min_data_in_leaf': 19, 'one_hot_max_size': 9, 'bagging_temperature': 4.467674076680571}. Best is trial 63 with value: 0.8894307421006861.
# AVG CV AUC: 	 0.8824118617395744
# [I 2023-01-14 19:02:52,401] Trial 89 finished with value: 0.8824118617395744 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.18958664856921142, 'l2_leaf_reg': 0.11342548498410242, 'colsample_bylevel': 0.0397661049049517, 'depth': 1, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 17, 'one_hot_max_size': 13}. Best is trial 63 with value: 0.8894307421006861.
# AVG CV AUC: 	 0.8440032163217978
# [I 2023-01-14 19:03:14,208] Trial 90 finished with value: 0.8440032163217978 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.0014928946467621055, 'l2_leaf_reg': 0.19163965638009023, 'colsample_bylevel': 0.036189453932593714, 'depth': 2, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 18, 'one_hot_max_size': 12}. Best is trial 63 with value: 0.8894307421006861.
# AVG CV AUC: 	 0.8887504658835221
# [I 2023-01-14 19:03:22,654] Trial 91 finished with value: 0.8887504658835221 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.42102126961373204, 'l2_leaf_reg': 0.10445968239161944, 'colsample_bylevel': 0.04394010344054845, 'depth': 1, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 17, 'one_hot_max_size': 11}. Best is trial 63 with value: 0.8894307421006861.
# AVG CV AUC: 	 0.8878700323012576
# [I 2023-01-14 19:03:37,079] Trial 92 finished with value: 0.8878700323012576 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.24756833452937535, 'l2_leaf_reg': 0.13196331051681326, 'colsample_bylevel': 0.04496618436506346, 'depth': 1, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 20, 'one_hot_max_size': 11}. Best is trial 63 with value: 0.8894307421006861.
# AVG CV AUC: 	 0.8876979142222161
# [I 2023-01-14 19:03:47,631] Trial 93 finished with value: 0.8876979142222161 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.3692774752284377, 'l2_leaf_reg': 0.08503625988302423, 'colsample_bylevel': 0.042600427693894, 'depth': 1, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 19, 'one_hot_max_size': 9}. Best is trial 63 with value: 0.8894307421006861.
# AVG CV AUC: 	 0.8867493236061456
# [I 2023-01-14 19:03:56,345] Trial 94 finished with value: 0.8867493236061456 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.4733947701215037, 'l2_leaf_reg': 0.10876172624782166, 'colsample_bylevel': 0.03795188064325099, 'depth': 1, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 17, 'one_hot_max_size': 10}. Best is trial 63 with value: 0.8894307421006861.
# AVG CV AUC: 	 0.8894850951782781
# [I 2023-01-14 19:04:02,880] Trial 95 finished with value: 0.8894850951782781 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.6917811416780869, 'l2_leaf_reg': 0.09057687056905092, 'colsample_bylevel': 0.04522494561718612, 'depth': 1, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 18, 'one_hot_max_size': 8}. Best is trial 95 with value: 0.8894850951782781.
# AVG CV AUC: 	 0.8366202566155461
# [I 2023-01-14 19:04:24,214] Trial 96 finished with value: 0.8366202566155461 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 7.011131298516656e-05, 'l2_leaf_reg': 0.07859135337311061, 'colsample_bylevel': 0.04587137542419635, 'depth': 1, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 20, 'one_hot_max_size': 8}. Best is trial 95 with value: 0.8894850951782781.
# AVG CV AUC: 	 0.8855345754593266
# [I 2023-01-14 19:04:28,510] Trial 97 finished with value: 0.8855345754593266 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.7796252183697324, 'l2_leaf_reg': 0.12487210460686672, 'colsample_bylevel': 0.062027924294693323, 'depth': 2, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 19, 'one_hot_max_size': 8}. Best is trial 95 with value: 0.8894850951782781.
# AVG CV AUC: 	 0.8861315965655756
# [I 2023-01-14 19:04:33,826] Trial 98 finished with value: 0.8861315965655756 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.5677458941085322, 'l2_leaf_reg': 0.15741651978317925, 'colsample_bylevel': 0.04873657476693955, 'depth': 2, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 18, 'one_hot_max_size': 9}. Best is trial 95 with value: 0.8894850951782781.
# AVG CV AUC: 	 0.886548734867413
# [I 2023-01-14 19:04:47,232] Trial 99 finished with value: 0.886548734867413 and parameters: {'loss_function': 'CrossEntropy', 'learning_rate': 0.2918578234692684, 'l2_leaf_reg': 0.09083266114409533, 'colsample_bylevel': 0.021686550157307978, 'depth': 1, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 17, 'one_hot_max_size': 7}. Best is trial 95 with value: 0.8894850951782781.

# %%
cat_study.best_value
# Out:
# 0.8894850951782781

# %%
cat_study.best_params
# Out:
# {'loss_function': 'CrossEntropy',
#  'learning_rate': 0.6917811416780869,
#  'l2_leaf_reg': 0.09057687056905092,
#  'colsample_bylevel': 0.04522494561718612,
#  'depth': 1,
#  'boosting_type': 'Plain',
#  'bootstrap_type': 'MVS',
#  'min_data_in_leaf': 18,
#  'one_hot_max_size': 8}

# %% [markdown]
# ### Before we implement stacking, let's reserve a validation set for validation/testing the meta leaners's predictions before we make the submission because the test set that comes with compeition has no y.
