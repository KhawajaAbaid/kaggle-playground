# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
from pathlib import Path
import xgboost as xgb
import lightgbm as lgbm
import catboost
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.metrics import roc_auc_score
from IPython.display import display
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, OrdinalEncoder
import optuna
from sklearn.preprocessing import StandardScaler
from scipy.linalg import norm

from category_encoders import LeaveOneOutEncoder

from IPython.display import display
from tqdm.notebook import tqdm
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %%
from warnings import filterwarnings
filterwarnings("ignore")

# %%
BASE_PATH = Path("/kaggle/input/playground-series-s3e4/")

train = pd.read_csv(BASE_PATH / "train.csv")
test = pd.read_csv(BASE_PATH / "test.csv")

print(f"Training dataset has {len(train)} rows with " \
                    f"{sum(train.Class) / len(train) * 100 :.2}% fraud rows.")
# Out:
# Training dataset has 219129 rows with 0.21% fraud rows.

# %%
train["Hour"] = ((train.Time // 3600) % 24).astype("int")
test["Hour"] = ((test.Time // 3600) % 24).astype("int")

def time_of_day(hour):
    if hour >=0 and hour <= 6:
        return "night"
    elif hour <= 12:
        return "morning"
    elif hour <= 18:
        return "afternoon"
    else:
        return "evening"

# %%
train["Hour"] = ((train.Time // 3600) % 24).astype("category")
test["Hour"] = ((test.Time // 3600) % 24).astype("category")

# %%
train["TimeOfDay"] = train.Hour.map(time_of_day)
test["TimeOfDay"] = test.Hour.map(time_of_day)

# %%
train["Day"] = (((train['Time'] // (24 * 3600)) % 7) + 1).astype("category")
test["Day"] = (((test["Time"] // (24 * 3600)) % 7) + 1).astype("category")

# %%
X = train.drop(columns=["id", "Class"])
y = train.Class
X_test = test.drop(columns=["id"])

# %%
numerical_feats = list(set(X.columns) - set(["TimeOfDay", "Day", "Hour"]))

# %%
# encoding
# feats_to_one_hot = ["TimeOfDay", "Day"]
feats_to_loo = ["Hour", "TimeOfDay", "Day"]

## leave one out
loo = LeaveOneOutEncoder()
loo.fit(X[feats_to_loo], y)
X[feats_to_loo] = loo.transform(X[feats_to_loo])
X_test[feats_to_loo] = loo.transform(X_test[feats_to_loo])

## one_hotting
# X = pd.get_dummies(X)


# scaling
feats_to_scale = numerical_feats
sc = StandardScaler()
sc.fit(X[feats_to_scale])
X[feats_to_scale] = sc.transform(X[feats_to_scale])
X_test[feats_to_scale] = sc.transform(X_test[feats_to_scale])

# %%
X.shape
# Out:
# (219129, 33)

# %% [markdown]
# # Tuning Catboost

# %%
def objective_cat(trial, X, y):
    param = {
        "n_estimators": trial.suggest_int("n_estimators", 100, 2000),
        "loss_function": trial.suggest_categorical("loss_function", ["CrossEntropy"]),
        "learning_rate": trial.suggest_loguniform("learning_rate", 1e-5, 1e0),
        "l2_leaf_reg": trial.suggest_loguniform("l2_leaf_reg", 1e-2, 1e0),
        "colsample_bylevel": trial.suggest_loguniform("colsample_bylevel", 0.01, 1.0),
        "depth": trial.suggest_int("depth", 1, 10),
        "boosting_type": trial.suggest_categorical("boosting_type", ["Ordered", "Plain"]),
        "bootstrap_type": trial.suggest_categorical("bootstrap_type", ["Bayesian", "Bernoulli", "MVS"]),
        "min_data_in_leaf": trial.suggest_int("min_data_in_leaf", 2, 20),
        "one_hot_max_size": trial.suggest_int("one_hot_max_size", 2, 20),
        "early_stopping_rounds": trial.suggest_int("early_stopping_rounds", 50, 200)
    }
    # Conditional Hyper-Parameters
    if param["bootstrap_type"] == "Bayesian":
        param["bagging_temperature"] = trial.suggest_float("bagging_temperature", 0, 10)
    elif param["bootstrap_type"] == "Bernoulli":
        param["subsample"] = trial.suggest_float("subsample", 0.1, 1)
    
    N_FOLDS = 8
    all_scores = np.zeros(N_FOLDS)

    skf = StratifiedKFold(n_splits=N_FOLDS, shuffle=True, random_state=1337)

    for fold_id, (train_idx, val_idx) in enumerate(skf.split(X, y)):
        
        X_tr, X_val = X.iloc[train_idx], X.iloc[val_idx]
        y_tr, y_val = y.iloc[train_idx], y.iloc[val_idx]

        cat_model = catboost.CatBoostClassifier(**param)
        cat_model.fit(X_tr, y_tr, eval_set=[(X_val, y_val)], verbose=False)
        
        y_preds = cat_model.predict_proba(X_val)[:, 1]
        all_scores[fold_id] = roc_auc_score(y_val, y_preds)
    
    auc = np.mean(all_scores)
    print(f"AVG CV AUC: \t {auc}")
    return auc

# %%
study_cat = optuna.create_study(direction="maximize", study_name="CatBoost Tuning")
func = lambda trial: objective_cat(trial, X, y)
study_cat.optimize(func, n_trials=100, show_progress_bar=True)
# Out:
# [I 2023-01-30 17:56:38,539] A new study created in memory with name: CatBoost Tuning
#   0%|          | 0/100 [00:00<?, ?it/s]
# AVG CV AUC: 	 0.8075797311669657
# [I 2023-01-30 18:00:23,770] Trial 0 finished with value: 0.8075797311669657 and parameters: {'n_estimators': 583, 'loss_function': 'CrossEntropy', 'learning_rate': 0.18040222719989238, 'l2_leaf_reg': 0.03186878527793749, 'colsample_bylevel': 0.019481488355564208, 'depth': 10, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'min_data_in_leaf': 15, 'one_hot_max_size': 4, 'early_stopping_rounds': 147, 'bagging_temperature': 5.46248767171551}. Best is trial 0 with value: 0.8075797311669657.
# AVG CV AUC: 	 0.8140868249879016
# [I 2023-01-30 18:01:25,530] Trial 1 finished with value: 0.8140868249879016 and parameters: {'n_estimators': 1412, 'loss_function': 'CrossEntropy', 'learning_rate': 0.11833324669151798, 'l2_leaf_reg': 0.06928566778103469, 'colsample_bylevel': 0.15111376024708675, 'depth': 4, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 13, 'one_hot_max_size': 19, 'early_stopping_rounds': 150, 'subsample': 0.5600809432055068}. Best is trial 1 with value: 0.8140868249879016.
# AVG CV AUC: 	 0.8068552878277238
# [I 2023-01-30 18:04:08,955] Trial 2 finished with value: 0.8068552878277238 and parameters: {'n_estimators': 1454, 'loss_function': 'CrossEntropy', 'learning_rate': 0.02740783700978924, 'l2_leaf_reg': 0.33871291858510183, 'colsample_bylevel': 0.7395676895870255, 'depth': 2, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 6, 'one_hot_max_size': 10, 'early_stopping_rounds': 64, 'subsample': 0.13297100954437988}. Best is trial 1 with value: 0.8140868249879016.
# AVG CV AUC: 	 0.7853263056152655
# [I 2023-01-30 18:07:34,463] Trial 3 finished with value: 0.7853263056152655 and parameters: {'n_estimators': 362, 'loss_function': 'CrossEntropy', 'learning_rate': 0.0013333685994706996, 'l2_leaf_reg': 0.06668603386564236, 'colsample_bylevel': 0.31641819252385317, 'depth': 1, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 6, 'one_hot_max_size': 12, 'early_stopping_rounds': 163, 'subsample': 0.853087969689507}. Best is trial 1 with value: 0.8140868249879016.
# AVG CV AUC: 	 0.7941144004543156
# [I 2023-01-30 18:13:18,883] Trial 4 finished with value: 0.7941144004543156 and parameters: {'n_estimators': 1991, 'loss_function': 'CrossEntropy', 'learning_rate': 0.1567729167935927, 'l2_leaf_reg': 0.09777800253817777, 'colsample_bylevel': 0.4853902602591705, 'depth': 1, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'min_data_in_leaf': 9, 'one_hot_max_size': 5, 'early_stopping_rounds': 98, 'bagging_temperature': 7.356336556305042}. Best is trial 1 with value: 0.8140868249879016.
# AVG CV AUC: 	 0.715411900828601
# [I 2023-01-30 18:15:10,563] Trial 5 finished with value: 0.715411900828601 and parameters: {'n_estimators': 830, 'loss_function': 'CrossEntropy', 'learning_rate': 0.6973695494993152, 'l2_leaf_reg': 0.033403789644110844, 'colsample_bylevel': 0.13621702571431318, 'depth': 6, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 14, 'one_hot_max_size': 3, 'early_stopping_rounds': 137}. Best is trial 1 with value: 0.8140868249879016.
# AVG CV AUC: 	 0.7937120466829396
# [I 2023-01-30 18:27:53,464] Trial 6 finished with value: 0.7937120466829396 and parameters: {'n_estimators': 1651, 'loss_function': 'CrossEntropy', 'learning_rate': 0.0028197419099851235, 'l2_leaf_reg': 0.012756526435919645, 'colsample_bylevel': 0.02108630226971317, 'depth': 4, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 14, 'one_hot_max_size': 10, 'early_stopping_rounds': 199}. Best is trial 1 with value: 0.8140868249879016.
# AVG CV AUC: 	 0.8069181535523762
# [I 2023-01-30 18:29:16,313] Trial 7 finished with value: 0.8069181535523762 and parameters: {'n_estimators': 1247, 'loss_function': 'CrossEntropy', 'learning_rate': 0.19219822225900507, 'l2_leaf_reg': 0.04226424215058412, 'colsample_bylevel': 0.019513138664399587, 'depth': 1, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'min_data_in_leaf': 9, 'one_hot_max_size': 2, 'early_stopping_rounds': 53, 'bagging_temperature': 6.089541385792165}. Best is trial 1 with value: 0.8140868249879016.
# AVG CV AUC: 	 0.7386525823183929
# [I 2023-01-30 18:30:59,111] Trial 8 finished with value: 0.7386525823183929 and parameters: {'n_estimators': 1928, 'loss_function': 'CrossEntropy', 'learning_rate': 0.06935357959333822, 'l2_leaf_reg': 0.04549773810988751, 'colsample_bylevel': 0.3685678883971493, 'depth': 10, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 12, 'one_hot_max_size': 8, 'early_stopping_rounds': 156, 'subsample': 0.28928503508417514}. Best is trial 1 with value: 0.8140868249879016.
# AVG CV AUC: 	 0.7954431131076343
# [I 2023-01-30 18:31:25,069] Trial 9 finished with value: 0.7954431131076343 and parameters: {'n_estimators': 146, 'loss_function': 'CrossEntropy', 'learning_rate': 0.0413225309607417, 'l2_leaf_reg': 0.013054465513590812, 'colsample_bylevel': 0.033607950175971256, 'depth': 7, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 17, 'one_hot_max_size': 10, 'early_stopping_rounds': 61}. Best is trial 1 with value: 0.8140868249879016.
# AVG CV AUC: 	 0.8011679864624768
# [I 2023-01-30 18:34:17,473] Trial 10 finished with value: 0.8011679864624768 and parameters: {'n_estimators': 1007, 'loss_function': 'CrossEntropy', 'learning_rate': 3.7599800229987164e-05, 'l2_leaf_reg': 0.2322131883489298, 'colsample_bylevel': 0.07482491447295044, 'depth': 4, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 20, 'one_hot_max_size': 20, 'early_stopping_rounds': 108, 'subsample': 0.5865918473311957}. Best is trial 1 with value: 0.8140868249879016.
# AVG CV AUC: 	 0.7871641427302998
# [I 2023-01-30 18:36:37,285] Trial 11 finished with value: 0.7871641427302998 and parameters: {'n_estimators': 739, 'loss_function': 'CrossEntropy', 'learning_rate': 0.8813641926526198, 'l2_leaf_reg': 0.8756138034466762, 'colsample_bylevel': 0.010333868738090043, 'depth': 10, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'min_data_in_leaf': 2, 'one_hot_max_size': 17, 'early_stopping_rounds': 180, 'bagging_temperature': 0.046787844911818866}. Best is trial 1 with value: 0.8140868249879016.
# AVG CV AUC: 	 0.814803945341126
# [I 2023-01-30 18:38:44,896] Trial 12 finished with value: 0.814803945341126 and parameters: {'n_estimators': 555, 'loss_function': 'CrossEntropy', 'learning_rate': 0.019312474382847482, 'l2_leaf_reg': 0.025058356711047624, 'colsample_bylevel': 0.08491761080189801, 'depth': 8, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'min_data_in_leaf': 17, 'one_hot_max_size': 15, 'early_stopping_rounds': 130, 'bagging_temperature': 9.832759501193523}. Best is trial 12 with value: 0.814803945341126.
# AVG CV AUC: 	 0.815404426666366
# [I 2023-01-30 18:41:31,589] Trial 13 finished with value: 0.815404426666366 and parameters: {'n_estimators': 1235, 'loss_function': 'CrossEntropy', 'learning_rate': 0.009899137038655782, 'l2_leaf_reg': 0.021974875912292014, 'colsample_bylevel': 0.13491962035934577, 'depth': 7, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 19, 'one_hot_max_size': 15, 'early_stopping_rounds': 120, 'subsample': 0.5829451569016635}. Best is trial 13 with value: 0.815404426666366.
# AVG CV AUC: 	 0.8139481522132569
# [I 2023-01-30 18:44:44,154] Trial 14 finished with value: 0.8139481522132569 and parameters: {'n_estimators': 1092, 'loss_function': 'CrossEntropy', 'learning_rate': 0.010438044788644896, 'l2_leaf_reg': 0.019396082742342655, 'colsample_bylevel': 0.07319698812776383, 'depth': 8, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'min_data_in_leaf': 20, 'one_hot_max_size': 15, 'early_stopping_rounds': 108, 'bagging_temperature': 9.330045903363603}. Best is trial 13 with value: 0.815404426666366.
# AVG CV AUC: 	 0.8041759036291074
# [I 2023-01-30 18:47:55,156] Trial 15 finished with value: 0.8041759036291074 and parameters: {'n_estimators': 469, 'loss_function': 'CrossEntropy', 'learning_rate': 0.007593704898100203, 'l2_leaf_reg': 0.010096089093293391, 'colsample_bylevel': 0.18353709483443603, 'depth': 8, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 17, 'one_hot_max_size': 14, 'early_stopping_rounds': 125, 'subsample': 0.9991649839546625}. Best is trial 13 with value: 0.815404426666366.
# AVG CV AUC: 	 0.81073167631737
# [I 2023-01-30 18:51:09,520] Trial 16 finished with value: 0.81073167631737 and parameters: {'n_estimators': 895, 'loss_function': 'CrossEntropy', 'learning_rate': 0.0010560966443040674, 'l2_leaf_reg': 0.02203905809150155, 'colsample_bylevel': 0.05637546269957876, 'depth': 8, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'min_data_in_leaf': 18, 'one_hot_max_size': 16, 'early_stopping_rounds': 85, 'bagging_temperature': 9.644290712717732}. Best is trial 13 with value: 0.815404426666366.
# AVG CV AUC: 	 0.8039727923575988
# [I 2023-01-30 18:52:33,568] Trial 17 finished with value: 0.8039727923575988 and parameters: {'n_estimators': 266, 'loss_function': 'CrossEntropy', 'learning_rate': 0.0004910074207066346, 'l2_leaf_reg': 0.02095957508789723, 'colsample_bylevel': 0.2271654973403322, 'depth': 6, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'min_data_in_leaf': 18, 'one_hot_max_size': 13, 'early_stopping_rounds': 125, 'bagging_temperature': 2.803996240512295}. Best is trial 13 with value: 0.815404426666366.
# AVG CV AUC: 	 0.8080268033614002
# [I 2023-01-30 18:54:42,919] Trial 18 finished with value: 0.8080268033614002 and parameters: {'n_estimators': 600, 'loss_function': 'CrossEntropy', 'learning_rate': 0.012952662504202612, 'l2_leaf_reg': 0.020656582299123552, 'colsample_bylevel': 0.11093105700324517, 'depth': 9, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 16, 'one_hot_max_size': 18, 'early_stopping_rounds': 83, 'subsample': 0.6967325638760908}. Best is trial 13 with value: 0.815404426666366.
# AVG CV AUC: 	 0.8105401333915574
# [I 2023-01-30 18:58:43,472] Trial 19 finished with value: 0.8105401333915574 and parameters: {'n_estimators': 1159, 'loss_function': 'CrossEntropy', 'learning_rate': 0.003629264705502473, 'l2_leaf_reg': 0.05516313634150054, 'colsample_bylevel': 0.09477544797343221, 'depth': 5, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 20, 'one_hot_max_size': 15, 'early_stopping_rounds': 172}. Best is trial 13 with value: 0.815404426666366.
# AVG CV AUC: 	 0.8154179428090149
# [I 2023-01-30 19:01:12,532] Trial 20 finished with value: 0.8154179428090149 and parameters: {'n_estimators': 1363, 'loss_function': 'CrossEntropy', 'learning_rate': 0.016473757872291613, 'l2_leaf_reg': 0.11940160423411061, 'colsample_bylevel': 0.052137644072930645, 'depth': 7, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 10, 'one_hot_max_size': 7, 'early_stopping_rounds': 135, 'subsample': 0.3763020709919437}. Best is trial 20 with value: 0.8154179428090149.
# AVG CV AUC: 	 0.8160591426348938
# [I 2023-01-30 19:03:14,150] Trial 21 finished with value: 0.8160591426348938 and parameters: {'n_estimators': 1623, 'loss_function': 'CrossEntropy', 'learning_rate': 0.021845582749717284, 'l2_leaf_reg': 0.11996737338637965, 'colsample_bylevel': 0.0529466154546771, 'depth': 7, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 10, 'one_hot_max_size': 7, 'early_stopping_rounds': 137, 'subsample': 0.3631825323001024}. Best is trial 21 with value: 0.8160591426348938.
# AVG CV AUC: 	 0.8207168794556973
# [I 2023-01-30 19:05:06,333] Trial 22 finished with value: 0.8207168794556973 and parameters: {'n_estimators': 1721, 'loss_function': 'CrossEntropy', 'learning_rate': 0.02305071379342274, 'l2_leaf_reg': 0.13702070180639067, 'colsample_bylevel': 0.04445167858751607, 'depth': 7, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 10, 'one_hot_max_size': 7, 'early_stopping_rounds': 112, 'subsample': 0.37617723841490125}. Best is trial 22 with value: 0.8207168794556973.
# AVG CV AUC: 	 0.8181813026621079
# [I 2023-01-30 19:07:03,228] Trial 23 finished with value: 0.8181813026621079 and parameters: {'n_estimators': 1743, 'loss_function': 'CrossEntropy', 'learning_rate': 0.027331785383201416, 'l2_leaf_reg': 0.13695902156918868, 'colsample_bylevel': 0.049003323643245625, 'depth': 7, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 10, 'one_hot_max_size': 7, 'early_stopping_rounds': 140, 'subsample': 0.3787814349638637}. Best is trial 22 with value: 0.8207168794556973.
# AVG CV AUC: 	 0.8166441231097996
# [I 2023-01-30 19:08:20,402] Trial 24 finished with value: 0.8166441231097996 and parameters: {'n_estimators': 1699, 'loss_function': 'CrossEntropy', 'learning_rate': 0.06298093151919212, 'l2_leaf_reg': 0.15281136184819627, 'colsample_bylevel': 0.04281584766191735, 'depth': 5, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 7, 'one_hot_max_size': 7, 'early_stopping_rounds': 114, 'subsample': 0.3867958809065812}. Best is trial 22 with value: 0.8207168794556973.
# AVG CV AUC: 	 0.8165378466345361
# [I 2023-01-30 19:09:56,219] Trial 25 finished with value: 0.8165378466345361 and parameters: {'n_estimators': 1766, 'loss_function': 'CrossEntropy', 'learning_rate': 0.04712999511271706, 'l2_leaf_reg': 0.17074157289023886, 'colsample_bylevel': 0.03596086437664412, 'depth': 5, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 6, 'one_hot_max_size': 8, 'early_stopping_rounds': 114, 'subsample': 0.40766162784104076}. Best is trial 22 with value: 0.8207168794556973.
# AVG CV AUC: 	 0.8145652348256012
# [I 2023-01-30 19:11:25,539] Trial 26 finished with value: 0.8145652348256012 and parameters: {'n_estimators': 1832, 'loss_function': 'CrossEntropy', 'learning_rate': 0.05904501791453403, 'l2_leaf_reg': 0.19734828869380838, 'colsample_bylevel': 0.03609202435941768, 'depth': 3, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 8, 'one_hot_max_size': 5, 'early_stopping_rounds': 94, 'subsample': 0.24254188823991948}. Best is trial 22 with value: 0.8207168794556973.
# AVG CV AUC: 	 0.7954539340158109
# [I 2023-01-30 19:11:49,087] Trial 27 finished with value: 0.7954539340158109 and parameters: {'n_estimators': 1575, 'loss_function': 'CrossEntropy', 'learning_rate': 0.35855354620683316, 'l2_leaf_reg': 0.09297570632693215, 'colsample_bylevel': 0.04665417432118388, 'depth': 6, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 4, 'one_hot_max_size': 6, 'early_stopping_rounds': 101, 'subsample': 0.45657113970534796}. Best is trial 22 with value: 0.8207168794556973.
# AVG CV AUC: 	 0.8117333936375046
# [I 2023-01-30 19:12:47,927] Trial 28 finished with value: 0.8117333936375046 and parameters: {'n_estimators': 1780, 'loss_function': 'CrossEntropy', 'learning_rate': 0.0877353968514687, 'l2_leaf_reg': 0.27045337023364074, 'colsample_bylevel': 0.028212520243985392, 'depth': 5, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 7, 'one_hot_max_size': 9, 'early_stopping_rounds': 89, 'subsample': 0.2797918657962363}. Best is trial 22 with value: 0.8207168794556973.
# AVG CV AUC: 	 0.78967659142143
# [I 2023-01-30 19:14:46,660] Trial 29 finished with value: 0.78967659142143 and parameters: {'n_estimators': 1524, 'loss_function': 'CrossEntropy', 'learning_rate': 0.3177868513573742, 'l2_leaf_reg': 0.15058990714707113, 'colsample_bylevel': 0.02599763847214294, 'depth': 9, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 11, 'one_hot_max_size': 4, 'early_stopping_rounds': 143, 'subsample': 0.46689444159114407}. Best is trial 22 with value: 0.8207168794556973.
# AVG CV AUC: 	 0.8052211633386599
# [I 2023-01-30 19:17:10,398] Trial 30 finished with value: 0.8052211633386599 and parameters: {'n_estimators': 1691, 'loss_function': 'CrossEntropy', 'learning_rate': 0.04567249030717179, 'l2_leaf_reg': 0.08449930075609624, 'colsample_bylevel': 0.013248923185604332, 'depth': 3, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 4, 'one_hot_max_size': 6, 'early_stopping_rounds': 76, 'subsample': 0.15525610229109385}. Best is trial 22 with value: 0.8207168794556973.
# AVG CV AUC: 	 0.8188844141357259
# [I 2023-01-30 19:19:00,989] Trial 31 finished with value: 0.8188844141357259 and parameters: {'n_estimators': 1815, 'loss_function': 'CrossEntropy', 'learning_rate': 0.04043793406363948, 'l2_leaf_reg': 0.162140496771391, 'colsample_bylevel': 0.03852106934029318, 'depth': 5, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 5, 'one_hot_max_size': 8, 'early_stopping_rounds': 113, 'subsample': 0.4113866611330247}. Best is trial 22 with value: 0.8207168794556973.
# AVG CV AUC: 	 0.8090801991275762
# [I 2023-01-30 19:19:47,600] Trial 32 finished with value: 0.8090801991275762 and parameters: {'n_estimators': 1875, 'loss_function': 'CrossEntropy', 'learning_rate': 0.11055372063830396, 'l2_leaf_reg': 0.14505794622872348, 'colsample_bylevel': 0.04205178284879983, 'depth': 6, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 4, 'one_hot_max_size': 8, 'early_stopping_rounds': 117, 'subsample': 0.33340861033287833}. Best is trial 22 with value: 0.8207168794556973.
# AVG CV AUC: 	 0.8180849829027137
# [I 2023-01-30 19:22:37,993] Trial 33 finished with value: 0.8180849829027137 and parameters: {'n_estimators': 1398, 'loss_function': 'CrossEntropy', 'learning_rate': 0.023403922048336214, 'l2_leaf_reg': 0.2901147386809188, 'colsample_bylevel': 0.061215093120744635, 'depth': 4, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 8, 'one_hot_max_size': 11, 'early_stopping_rounds': 149, 'subsample': 0.4634784034464157}. Best is trial 22 with value: 0.8207168794556973.
# AVG CV AUC: 	 0.8207288498809959
# [I 2023-01-30 19:25:21,069] Trial 34 finished with value: 0.8207288498809959 and parameters: {'n_estimators': 1397, 'loss_function': 'CrossEntropy', 'learning_rate': 0.023727758703827706, 'l2_leaf_reg': 0.36581785392534655, 'colsample_bylevel': 0.06489619771005858, 'depth': 4, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 11, 'one_hot_max_size': 11, 'early_stopping_rounds': 150, 'subsample': 0.4760930211240077}. Best is trial 34 with value: 0.8207288498809959.
# AVG CV AUC: 	 0.8205279372943546
# [I 2023-01-30 19:27:30,564] Trial 35 finished with value: 0.8205279372943546 and parameters: {'n_estimators': 1496, 'loss_function': 'CrossEntropy', 'learning_rate': 0.027166383269996156, 'l2_leaf_reg': 0.4005438076519247, 'colsample_bylevel': 0.06588175211024602, 'depth': 6, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 12, 'one_hot_max_size': 12, 'early_stopping_rounds': 160, 'subsample': 0.495875481652097}. Best is trial 34 with value: 0.8207288498809959.
# [W 2023-01-30 19:36:16,181] Trial 36 failed with parameters: {'n_estimators': 1469, 'loss_function': 'CrossEntropy', 'learning_rate': 0.006004387367712969, 'l2_leaf_reg': 0.3872844727293207, 'colsample_bylevel': 0.06671810767178177, 'depth': 3, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 12, 'one_hot_max_size': 12, 'early_stopping_rounds': 161, 'subsample': 0.5058431164431519} because of the following error: KeyboardInterrupt('').
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/optuna/study/_optimize.py", line 200, in _run_trial
#     value_or_values = func(trial)
#   File "/tmp/ipykernel_27/714323211.py", line 2, in <lambda>
#     func = lambda trial: objective_cat(trial, X, y)
#   File "/tmp/ipykernel_27/1472355869.py", line 32, in objective_cat
#     cat_model.fit(X_tr, y_tr, eval_set=[(X_val, y_val)], verbose=False)
#   File "/opt/conda/lib/python3.7/site-packages/catboost/core.py", line 5130, in fit
#     silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#   File "/opt/conda/lib/python3.7/site-packages/catboost/core.py", line 2360, in _fit
#     train_params["init_model"]
#   File "/opt/conda/lib/python3.7/site-packages/catboost/core.py", line 1759, in _train
#     self._object._train(train_pool, test_pool, params, allow_clear_pool, init_model._object if init_model else None)
#   File "_catboost.pyx", line 4623, in _catboost._CatBoost._train
#   File "_catboost.pyx", line 4672, in _catboost._CatBoost._train
# KeyboardInterrupt
# [W 2023-01-30 19:36:16,186] Trial 36 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_27/714323211.py in <module>
#       1 study_cat = optuna.create_study(direction="maximize", study_name="CatBoost Tuning")
#       2 func = lambda trial: objective_cat(trial, X, y)
# ----> 3 study_cat.optimize(func, n_trials=100, show_progress_bar=True)
#
# /opt/conda/lib/python3.7/site-packages/optuna/study/study.py in optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     432             callbacks=callbacks,
#     433             gc_after_trial=gc_after_trial,
# --> 434             show_progress_bar=show_progress_bar,
#     435         )
#     436
#
# /opt/conda/lib/python3.7/site-packages/optuna/study/_optimize.py in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      74                 reseed_sampler_rng=False,
#      75                 time_start=None,
# ---> 76                 progress_bar=progress_bar,
#      77             )
#      78         else:
#
# /opt/conda/lib/python3.7/site-packages/optuna/study/_optimize.py in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     161
#     162         try:
# --> 163             frozen_trial = _run_trial(study, func, catch)
#     164         finally:
#     165             # The following line mitigates memory problems that can be occurred in some
#
# /opt/conda/lib/python3.7/site-packages/optuna/study/_optimize.py in _run_trial(study, func, catch)
#     249         and not isinstance(func_err, catch)
#     250     ):
# --> 251         raise func_err
#     252     return frozen_trial
#     253
#
# /opt/conda/lib/python3.7/site-packages/optuna/study/_optimize.py in _run_trial(study, func, catch)
#     198     with get_heartbeat_thread(trial._trial_id, study._storage):
#     199         try:
# --> 200             value_or_values = func(trial)
#     201         except exceptions.TrialPruned as e:
#     202             # TODO(mamu): Handle multi-objective cases.
#
# /tmp/ipykernel_27/714323211.py in <lambda>(trial)
#       1 study_cat = optuna.create_study(direction="maximize", study_name="CatBoost Tuning")
# ----> 2 func = lambda trial: objective_cat(trial, X, y)
#       3 study_cat.optimize(func, n_trials=100, show_progress_bar=True)
#
# /tmp/ipykernel_27/1472355869.py in objective_cat(trial, X, y)
#      30
#      31         cat_model = catboost.CatBoostClassifier(**param)
# ---> 32         cat_model.fit(X_tr, y_tr, eval_set=[(X_val, y_val)], verbose=False)
#      33
#      34         y_preds = cat_model.predict_proba(X_val)[:, 1]
#
# /opt/conda/lib/python3.7/site-packages/catboost/core.py in fit(self, X, y, cat_features, text_features, embedding_features, sample_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    5128         self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline, use_best_model,
#    5129                   eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period,
# -> 5130                   silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    5131         return self
#    5132
#
# /opt/conda/lib/python3.7/site-packages/catboost/core.py in _fit(self, X, y, cat_features, text_features, embedding_features, pairs, sample_weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    2358                 params,
#    2359                 allow_clear_pool,
# -> 2360                 train_params["init_model"]
#    2361             )
#    2362
#
# /opt/conda/lib/python3.7/site-packages/catboost/core.py in _train(self, train_pool, test_pool, params, allow_clear_pool, init_model)
#    1757
#    1758     def _train(self, train_pool, test_pool, params, allow_clear_pool, init_model):
# -> 1759         self._object._train(train_pool, test_pool, params, allow_clear_pool, init_model._object if init_model else None)
#    1760         self._set_trained_model_attributes()
#    1761
#
# _catboost.pyx in _catboost._CatBoost._train()
#
# _catboost.pyx in _catboost._CatBoost._train()
#
# KeyboardInterrupt:
