# %%
# !pip install --upgrade tensorflow

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
from pathlib import Path
import xgboost as xgb
import lightgbm as lgbm
import catboost

from sklearn.model_selection import KFold, train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import OrdinalEncoder, StandardScaler
from IPython.display import display
import optuna

# %%
from warnings import filterwarnings
filterwarnings("ignore")

# %%
# setting a base path variable for easy access
BASE_PATH = Path("/kaggle/input/playground-series-s3e6")
train = pd.read_csv(BASE_PATH / "train.csv").drop(columns=["id"])

test = pd.read_csv(BASE_PATH / "test.csv")
test_idx = test.id
test = test.drop(columns=["id"])

# %%
# Note that we won't seprate the target variable since we won't use cross validation for training models
X = train.drop(columns="price")
y = train.price

# %%
pd.DataFrame({"N_Folds": [3, 4, 5], "XGB_results": [20, 20, 30]})
# Out:
#    N_Folds  XGB_results
# 0        3           20
# 1        4           20
# 2        5           30

# %%
# let's find the fold with lowest rmse score and use that to overfit publicLeaderboard :D
# we will use three models to calculate the rmse, and will find which fold on average gives the least rmse
N_FOLDS = [3, 4, 5, 6, 7, 8]

all_results = []
for N_F in N_FOLDS:
    print("Number of folds: ", N_F)
    kf = KFold(n_splits=N_F, random_state=1337, shuffle=True)
    cv_scores = np.zeros(N_F)

    for fold_id, (train_idx, val_idx) in enumerate(kf.split(X)):
        print("\t fold_id: ", fold_id)  
        fold_result = {}
        X_tr, X_val = X.iloc[train_idx], X.iloc[val_idx]
        y_tr, y_val = y.iloc[train_idx], y.iloc[val_idx]

        fold_data = {"train": X_tr, "train_target": y_tr, 
                     "val": X_val, "val_target": y_val}
        all_folds_datasets["fold_"+str(fold_id+1)] = fold_data

        xgb_model = xgb.XGBRegressor(tree_method="gpu_hist")
        xgb_model.fit(X_tr, y_tr, verbose=False)
        y_preds_xgb = xgb_model.predict(X_val)
        rmse_xgb = mean_squared_error(y_val, y_preds_xgb, squared=False)
        print("\t\t XGBoost: ", rmse_xgb)
        
        lgbm_model = lgbm.LGBMRegressor(device_type="gpu")
        lgbm_model.fit(X_tr, y_tr, verbose=-1)
        y_preds_lgbm = lgbm_model.predict(X_val)
        rmse_lgbm = mean_squared_error(y_val, y_preds_lgbm, squared=False)
        print("\t\t LGBM: ", rmse_lgbm)
        
        cat_model = catboost.CatBoostRegressor()
        cat_model.fit(X_tr, y_tr, verbose=False)
        y_preds_cat = cat_model.predict(X_val)
        rmse_cat = mean_squared_error(y_val, y_preds_cat, squared=False)
        print("\t\t CATBOOST: ", rmse_cat)
        
        average = np.mean([rmse_xgb, rmse_lgbm, rmse_cat])
        print("\t\t\t AVERAGE: ", average)

#         print(f"Fold {fold_id+1} | RMSE: {rmse}")
    #     print("Fold length: ",len(X_tr))
#     avg_rmse = np.mean(cv_scores)
#     print(f"Average RMSE: {avg_rmse}")
# Out:
# Number of folds:  3
# 	 fold_id:  0
# 		 XGBoost:  159432.1585679272
# 		 LGBM:  145281.55768531864
# 		 CATBOOST:  147042.50201901066
# 			 AVERAGE:  150585.40609075216
# 	 fold_id:  1
# 		 XGBoost:  176691.47354847848
# 		 LGBM:  170494.04018474574
# 		 CATBOOST:  169620.16982847906
# 			 AVERAGE:  172268.56118723445
# 	 fold_id:  2
# 		 XGBoost:  202772.90152157153
# 		 LGBM:  204252.09813681437
# 		 CATBOOST:  198732.53077452036
# 			 AVERAGE:  201919.17681096875
# Number of folds:  4
# 	 fold_id:  0
# 		 XGBoost:  158581.13665705323
# 		 LGBM:  164256.53966637346
# 		 CATBOOST:  158943.65310916188
# 			 AVERAGE:  160593.77647752952
# 	 fold_id:  1
# 		 XGBoost:  162610.85191605688
# 		 LGBM:  145905.82938447042
# 		 CATBOOST:  147061.81966354063
# 			 AVERAGE:  151859.50032135597
# 	 fold_id:  2
# 		 XGBoost:  212867.11395255371
# 		 LGBM:  210559.09452542642
# 		 CATBOOST:  216335.28822046594
# 			 AVERAGE:  213253.83223281536
# 	 fold_id:  3
# 		 XGBoost:  155590.86809423703
# 		 LGBM:  174764.44050747747
# 		 CATBOOST:  146728.93826268555
# 			 AVERAGE:  159028.08228813336
# Number of folds:  5
# 	 fold_id:  0
# 		 XGBoost:  176911.5290368936
# 		 LGBM:  171193.35587407096
# 		 CATBOOST:  175459.06220995876
# 			 AVERAGE:  174521.31570697445
# 	 fold_id:  1
# 		 XGBoost:  128748.45253518694
# 		 LGBM:  132547.97002347856
# 		 CATBOOST:  134089.41009170283
# 			 AVERAGE:  131795.2775501228
# 	 fold_id:  2
# 		 XGBoost:  126922.99478477816
# 		 LGBM:  134726.09754756416
# 		 CATBOOST:  149865.6870895037
# 			 AVERAGE:  137171.59314061535
# 	 fold_id:  3
# 		 XGBoost:  242898.18165378735
# 		 LGBM:  251979.54133014765
# 		 CATBOOST:  232504.99237738005
# 			 AVERAGE:  242460.90512043834
# 	 fold_id:  4
# 		 XGBoost:  157344.77385534006
# 		 LGBM:  160091.5061689458
# 		 CATBOOST:  149976.49864508043
# 			 AVERAGE:  155804.25955645545
# Number of folds:  6
# 	 fold_id:  0
# 		 XGBoost:  170859.26322343652
# 		 LGBM:  153827.759359531
# 		 CATBOOST:  154649.45569301175
# 			 AVERAGE:  159778.8260919931
# 	 fold_id:  1
# 		 XGBoost:  123188.28863505105
# 		 LGBM:  134891.05248756046
# 		 CATBOOST:  123613.34836466474
# 			 AVERAGE:  127230.89649575875
# 	 fold_id:  2
# 		 XGBoost:  175428.94625400752
# 		 LGBM:  178077.47583327795
# 		 CATBOOST:  197954.47301934636
# 			 AVERAGE:  183820.29836887727
# 	 fold_id:  3
# 		 XGBoost:  169982.98174502645
# 		 LGBM:  159576.631361945
# 		 CATBOOST:  183726.37843652844
# 			 AVERAGE:  171095.33051449998
# 	 fold_id:  4
# 		 XGBoost:  224914.53032286416
# 		 LGBM:  227737.27404525425
# 		 CATBOOST:  227547.3641062055
# 			 AVERAGE:  226733.05615810797
# 	 fold_id:  5
# 		 XGBoost:  170795.16789472537
# 		 LGBM:  171627.83822464844
# 		 CATBOOST:  178509.20214203765
# 			 AVERAGE:  173644.0694204705
# Number of folds:  7
# 	 fold_id:  0
# 		 XGBoost:  175528.40083978666
# 		 LGBM:  165017.93479934585
# 		 CATBOOST:  187344.38129317973
# 			 AVERAGE:  175963.57231077075
# 	 fold_id:  1
# 		 XGBoost:  131699.03394321847
# 		 LGBM:  151726.70007799056
# 		 CATBOOST:  141025.40544568378
# 			 AVERAGE:  141483.71315563095
# 	 fold_id:  2
# 		 XGBoost:  171858.39541925062
# 		 LGBM:  174818.5135535224
# 		 CATBOOST:  169412.2758375463
# 			 AVERAGE:  172029.72827010645
# 	 fold_id:  3
# 		 XGBoost:  103601.7152884681
# 		 LGBM:  107677.09978670951
# 		 CATBOOST:  97176.69982007775
# 			 AVERAGE:  102818.50496508511
# 	 fold_id:  4
# 		 XGBoost:  232505.69306707775
# 		 LGBM:  215654.85158609378
# 		 CATBOOST:  228866.1333760377
# 			 AVERAGE:  225675.55934306976
# 	 fold_id:  5
# 		 XGBoost:  182578.33699081428
# 		 LGBM:  199557.93390968553
# 		 CATBOOST:  178011.9012847809
# 			 AVERAGE:  186716.05739509358
# 	 fold_id:  6
# 		 XGBoost:  170450.69481565035
# 		 LGBM:  171246.23763418722
# 		 CATBOOST:  203352.0884264531
# 			 AVERAGE:  181683.00695876355
# Number of folds:  8
# 	 fold_id:  0
# 		 XGBoost:  185137.4392055286
# 		 LGBM:  175425.10068424785
# 		 CATBOOST:  180828.47069014714
# 			 AVERAGE:  180463.6701933079
# 	 fold_id:  1
# 		 XGBoost:  140142.53591379174
# 		 LGBM:  151872.31799197523
# 		 CATBOOST:  136981.11249192973
# 			 AVERAGE:  142998.6554658989
# 	 fold_id:  2
# 		 XGBoost:  77068.04573786366
# 		 LGBM:  75316.96502194248
# 		 CATBOOST:  64595.906140480845
# 			 AVERAGE:  72326.97230009566
# 	 fold_id:  3
# 		 XGBoost:  198702.14350566862
# 		 LGBM:  204540.61370152916
# 		 CATBOOST:  195107.60814565525
# 			 AVERAGE:  199450.12178428433
# 	 fold_id:  4
# 		 XGBoost:  132782.73050542094
# 		 LGBM:  71350.97721504518
# 		 CATBOOST:  101654.65184770348
# 			 AVERAGE:  101929.45318938988
# 	 fold_id:  5
# 		 XGBoost:  296780.37450702506
# 		 LGBM:  290320.46996886167
# 		 CATBOOST:  282520.999136767
# 			 AVERAGE:  289873.9478708846
# 	 fold_id:  6
# 		 XGBoost:  191349.7818681119
# 		 LGBM:  206602.4636575716
# 		 CATBOOST:  185916.2086293194
# 			 AVERAGE:  194622.81805166765
# 	 fold_id:  7
# 		 XGBoost:  91946.05486614653
# 		 LGBM:  94412.95683596819
# 		 CATBOOST:  106795.62456595314
# 			 AVERAGE:  97718.21208935596

# %%
del all_folds_datasets

# %%
N_FOLDS = 8

all_folds_datasets = {}
cv_scores = np.zeros(N_FOLDS)
kf_8 = KFold(n_splits=N_FOLDS, shuffle=True, random_state=1337)

for fold_id, (train_idx, val_idx) in enumerate(kf_8.split(X)):
#     print("\t fold_id: ", fold_id+1)  
    X_tr, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_tr, y_val = y.iloc[train_idx], y.iloc[val_idx]

    fold_data = {"train": X_tr, "train_target": y_tr, 
                 "val": X_val, "val_target": y_val}
    all_folds_datasets["fold_"+str(fold_id+1)] = fold_data
    
    xgb_model = xgb.XGBRegressor(tree_method="gpu_hist")
    xgb_model.fit(X_tr, y_tr, verbose=False)
    y_preds_xgb = xgb_model.predict(X_val)
    rmse = mean_squared_error(y_val, y_preds_xgb, squared=False)

    print(f"Fold {fold_id+1} | RMSE: {rmse}")
    cv_scores[fold_id] = rmse
#         print("Fold length: ",len(X_tr))
avg_rmse = np.mean(cv_scores)
print(f"Average RMSE: {avg_rmse}")
# Out:
# Fold 1 | RMSE: 185137.4392055286
# Fold 2 | RMSE: 140142.53591379174
# Fold 3 | RMSE: 77068.04573786366
# Fold 4 | RMSE: 198702.14350566862
# Fold 5 | RMSE: 132782.73050542094
# Fold 6 | RMSE: 296780.37450702506
# Fold 7 | RMSE: 191349.7818681119
# Fold 8 | RMSE: 91946.05486614653
# Average RMSE: 164238.63826369465

# %%
all_folds_datasets.keys()
# Out:
# dict_keys(['fold_1', 'fold_2', 'fold_3', 'fold_4', 'fold_5', 'fold_6', 'fold_7', 'fold_8'])

# %%
# let's use every fold 3 train data

f_X = all_folds_datasets["fold_3"]["train"]
f_y = all_folds_datasets["fold_3"]["train_target"]

X_val = all_folds_datasets["fold_3"]["val"]
y_val = all_folds_datasets["fold_3"]["val_target"]

# %%
# def objective_xgb(trial, X, y, X_val, y_val):
#     params = {
#         'tree_method': "gpu_hist",
#         'n_estimators': trial.suggest_int('n_estimators', 50, 600),
#         'max_depth': trial.suggest_int('max_depth', 2, 30),
#         'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
#         'min_child_weight': trial.suggest_int('min_child_weight', 1, 30),
#         'gamma': trial.suggest_loguniform('gamma', 0.00001, 0.3),
#         'subsample': trial.suggest_float('subsample', 0.2, 1.0, step=0.05),
#         'colsample_bytree': trial.suggest_float('colsample_bytree', 0.2, 1.0, step=0.05),
#         'early_stopping_rounds': trial.suggest_int("early_stoppig_rounds", 40, 100)
#     }
    
    
#     model = xgb.XGBRegressor(**params)
#     model.fit(X, y, eval_set=[(X_val, y_val)], verbose=False)

#     y_pred = model.predict(X_val)

#     auc = mean_squared_error(y_val, y_pred, squared=False)        
        
#     print(f"AUC: {auc}")
    
#     return auc

# %%
# study_xgb = optuna.create_study(study_name="xgboost_tuning", direction="minimize")
# func = lambda trial: objective_xgb(trial, f_X, f_y, X_val, y_val)
# study_xgb.optimize(func, n_trials=100)
# Out:
# [I 2023-02-16 09:58:40,643] A new study created in memory with name: xgboost_tuning
# [I 2023-02-16 09:58:52,527] Trial 0 finished with value: 1196424.893800973 and parameters: {'n_estimators': 476, 'max_depth': 19, 'learning_rate': 0.010792949917844335, 'min_child_weight': 25, 'gamma': 0.0833587296491035, 'subsample': 0.8, 'colsample_bytree': 0.2, 'early_stoppig_rounds': 96}. Best is trial 0 with value: 1196424.893800973.
# AUC: 1196424.893800973
# [W 2023-02-16 09:59:47,143] Trial 1 failed with parameters: {'n_estimators': 283, 'max_depth': 26, 'learning_rate': 0.023662574432960402, 'min_child_weight': 22, 'gamma': 0.21335029876439185, 'subsample': 0.6000000000000001, 'colsample_bytree': 0.8500000000000001, 'early_stoppig_rounds': 63} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/optuna/study/_optimize.py", line 200, in _run_trial
#     value_or_values = func(trial)
#   File "/tmp/ipykernel_24/1245654727.py", line 2, in <lambda>
#     func = lambda trial: objective_xgb(trial, f_X, f_y, X_val, y_val)
#   File "/tmp/ipykernel_24/3155177625.py", line 16, in objective_xgb
#     model.fit(X, y, eval_set=[(X_val, y_val)], verbose=False)
#   File "/opt/conda/lib/python3.7/site-packages/xgboost/core.py", line 575, in inner_f
#     return f(**kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py", line 972, in fit
#     callbacks=callbacks,
#   File "/opt/conda/lib/python3.7/site-packages/xgboost/core.py", line 575, in inner_f
#     return f(**kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/xgboost/training.py", line 181, in train
#     bst.update(dtrain, i, obj)
#   File "/opt/conda/lib/python3.7/site-packages/xgboost/core.py", line 1780, in update
#     dtrain.handle))
# KeyboardInterrupt
# [W 2023-02-16 09:59:47,144] Trial 1 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_24/1245654727.py in <module>
#       1 study_xgb = optuna.create_study(study_name="xgboost_tuning", direction="minimize")
#       2 func = lambda trial: objective_xgb(trial, f_X, f_y, X_val, y_val)
# ----> 3 study_xgb.optimize(func, n_trials=100)
#
# /opt/conda/lib/python3.7/site-packages/optuna/study/study.py in optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     432             callbacks=callbacks,
#     433             gc_after_trial=gc_after_trial,
# --> 434             show_progress_bar=show_progress_bar,
#     435         )
#     436
#
# /opt/conda/lib/python3.7/site-packages/optuna/study/_optimize.py in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      74                 reseed_sampler_rng=False,
#      75                 time_start=None,
# ---> 76                 progress_bar=progress_bar,
#      77             )
#      78         else:
#
# /opt/conda/lib/python3.7/site-packages/optuna/study/_optimize.py in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     161
#     162         try:
# --> 163             frozen_trial = _run_trial(study, func, catch)
#     164         finally:
#     165             # The following line mitigates memory problems that can be occurred in some
#
# /opt/conda/lib/python3.7/site-packages/optuna/study/_optimize.py in _run_trial(study, func, catch)
#     249         and not isinstance(func_err, catch)
#     250     ):
# --> 251         raise func_err
#     252     return frozen_trial
#     253
#
# /opt/conda/lib/python3.7/site-packages/optuna/study/_optimize.py in _run_trial(study, func, catch)
#     198     with get_heartbeat_thread(trial._trial_id, study._storage):
#     199         try:
# --> 200             value_or_values = func(trial)
#     201         except exceptions.TrialPruned as e:
#     202             # TODO(mamu): Handle multi-objective cases.
#
# /tmp/ipykernel_24/1245654727.py in <lambda>(trial)
#       1 study_xgb = optuna.create_study(study_name="xgboost_tuning", direction="minimize")
# ----> 2 func = lambda trial: objective_xgb(trial, f_X, f_y, X_val, y_val)
#       3 study_xgb.optimize(func, n_trials=100)
#
# /tmp/ipykernel_24/3155177625.py in objective_xgb(trial, X, y, X_val, y_val)
#      14
#      15     model = xgb.XGBRegressor(**params)
# ---> 16     model.fit(X, y, eval_set=[(X_val, y_val)], verbose=False)
#      17
#      18     y_pred = model.predict(X_val)
#
# /opt/conda/lib/python3.7/site-packages/xgboost/core.py in inner_f(*args, **kwargs)
#     573         for k, arg in zip(sig.parameters, args):
#     574             kwargs[k] = arg
# --> 575         return f(**kwargs)
#     576
#     577     return inner_f
#
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py in fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#     970             verbose_eval=verbose,
#     971             xgb_model=model,
# --> 972             callbacks=callbacks,
#     973         )
#     974
#
# /opt/conda/lib/python3.7/site-packages/xgboost/core.py in inner_f(*args, **kwargs)
#     573         for k, arg in zip(sig.parameters, args):
#     574             kwargs[k] = arg
# --> 575         return f(**kwargs)
#     576
#     577     return inner_f
#
# /opt/conda/lib/python3.7/site-packages/xgboost/training.py in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     179         if cb_container.before_iteration(bst, i, dtrain, evals):
#     180             break
# --> 181         bst.update(dtrain, i, obj)
#     182         if cb_container.after_iteration(bst, i, dtrain, evals):
#     183             break
#
# /opt/conda/lib/python3.7/site-packages/xgboost/core.py in update(self, dtrain, iteration, fobj)
#    1778             _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#    1779                                                     ctypes.c_int(iteration),
# -> 1780                                                     dtrain.handle))
#    1781         else:
#    1782             pred = self.predict(dtrain, output_margin=True, training=True)
#
# KeyboardInterrupt:

# %%
# from optuna.integration import LightGBMPruningCallback

# def objective_lgbm(trial, f_X, f_y, X_val, y_val):
#     param_grid = {
#         "device_type": "gpu",
#         "n_estimators": trial.suggest_int("n_estimators", 100, 2000),
#         "num_rounds": trial.suggest_int("num_rounds", 100, 1000),
#         "learning_rate": trial.suggest_float("learning_rate", 0.0001, 0.3),
#         "num_leaves": trial.suggest_int("num_leaves", 2, 300),
#         "max_depth": trial.suggest_int("max_depth", 2, 30),
#         "min_data_in_leaf": trial.suggest_int("min_data_in_leaf", 10, 1000),
#         "lambda_l1": trial.suggest_loguniform('lambda_l1', 0.00001, 1.0),
#         "lambda_l2": trial.suggest_loguniform('lambda_l2', 0.00001, 1.0),
#         "min_gain_to_split": trial.suggest_float("min_gain_to_split", 0, 15),
#         "bagging_fraction":  trial.suggest_loguniform('bagging_fraction', 0.2, 1.0),
#         "feature_fraction": trial.suggest_loguniform('feature_fraction', 0.2, 1.0),
#         "early_stopping_rounds": trial.suggest_int("early_stopping_rounds", 50, 200),
#         "verbose": -1,
#     }

            
#     model = lgbm.LGBMRegressor(**param_grid)
#     model.fit(f_X, f_y,
#         eval_set=[(X_val, y_val)],
#         eval_metric="auc",
#         verbose=-1,
#     )
#     y_preds = model.predict(X_val)
#     rmse = mean_squared_error(y_val, y_preds, squared=False)
    
#     print(f"RMSE: \t {rmse}")
#     return rmse

# %%
# study_lgbm = optuna.create_study(direction="minimize", study_name="LGBM Tuning")
# func = lambda trial: objective_lgbm(trial, f_X, f_y, X_val, y_val)
# study_lgbm.optimize(func, n_trials=100, show_progress_bar=True)
# Out:
# [I 2023-02-16 10:57:34,350] A new study created in memory with name: LGBM Tuning
#   0%|          | 0/100 [00:00<?, ?it/s]
# [LightGBM] [Warning] lambda_l2 is set=0.059767748509954435, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.059767748509954435
# [LightGBM] [Warning] early_stopping_round is set=87, early_stopping_rounds=87 will be ignored. Current value: early_stopping_round=87
# [LightGBM] [Warning] bagging_fraction is set=0.6931773116431083, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6931773116431083
# [LightGBM] [Warning] feature_fraction is set=0.5106276523995611, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5106276523995611
# [LightGBM] [Warning] min_data_in_leaf is set=205, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=205
# [LightGBM] [Warning] num_iterations is set=626, num_rounds=626 will be ignored. Current value: num_iterations=626
# [LightGBM] [Warning] min_gain_to_split is set=12.797260236190297, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=12.797260236190297
# [LightGBM] [Warning] lambda_l1 is set=0.21621144981711818, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.21621144981711818
# RMSE: 	 2935219.9329150515
# [I 2023-02-16 10:57:35,084] Trial 0 finished with value: 2935219.9329150515 and parameters: {'n_estimators': 1893, 'num_rounds': 626, 'learning_rate': 0.051941549782402605, 'num_leaves': 160, 'max_depth': 13, 'min_data_in_leaf': 205, 'lambda_l1': 0.21621144981711818, 'lambda_l2': 0.059767748509954435, 'min_gain_to_split': 12.797260236190297, 'bagging_fraction': 0.6931773116431083, 'feature_fraction': 0.5106276523995611, 'early_stopping_rounds': 87}. Best is trial 0 with value: 2935219.9329150515.
# [LightGBM] [Warning] lambda_l2 is set=2.3972883761592648e-05, reg_lambda=0.0 will be ignored. Current value: lambda_l2=2.3972883761592648e-05
# [LightGBM] [Warning] early_stopping_round is set=163, early_stopping_rounds=163 will be ignored. Current value: early_stopping_round=163
# [LightGBM] [Warning] bagging_fraction is set=0.949340498769101, subsample=1.0 will be ignored. Current value: bagging_fraction=0.949340498769101
# [LightGBM] [Warning] feature_fraction is set=0.6006627724566631, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6006627724566631
# [LightGBM] [Warning] min_data_in_leaf is set=561, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=561
# [LightGBM] [Warning] num_iterations is set=529, num_rounds=529 will be ignored. Current value: num_iterations=529
# [LightGBM] [Warning] min_gain_to_split is set=0.11900481077082525, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=0.11900481077082525
# [LightGBM] [Warning] lambda_l1 is set=0.019227984817903433, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.019227984817903433
# RMSE: 	 2897145.494925644
# [I 2023-02-16 10:57:35,789] Trial 1 finished with value: 2897145.494925644 and parameters: {'n_estimators': 1123, 'num_rounds': 529, 'learning_rate': 0.225405395069397, 'num_leaves': 193, 'max_depth': 30, 'min_data_in_leaf': 561, 'lambda_l1': 0.019227984817903433, 'lambda_l2': 2.3972883761592648e-05, 'min_gain_to_split': 0.11900481077082525, 'bagging_fraction': 0.949340498769101, 'feature_fraction': 0.6006627724566631, 'early_stopping_rounds': 163}. Best is trial 1 with value: 2897145.494925644.
# [LightGBM] [Warning] lambda_l2 is set=0.028305359158491, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.028305359158491
# [LightGBM] [Warning] early_stopping_round is set=50, early_stopping_rounds=50 will be ignored. Current value: early_stopping_round=50
# [LightGBM] [Warning] bagging_fraction is set=0.5989717336485276, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5989717336485276
# [LightGBM] [Warning] feature_fraction is set=0.4658280476050427, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4658280476050427
# [LightGBM] [Warning] min_data_in_leaf is set=712, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=712
# [LightGBM] [Warning] num_iterations is set=353, num_rounds=353 will be ignored. Current value: num_iterations=353
# [LightGBM] [Warning] min_gain_to_split is set=11.074712202921736, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=11.074712202921736
# [LightGBM] [Warning] lambda_l1 is set=0.008663796190634803, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.008663796190634803
# RMSE: 	 2914812.948813081
# [I 2023-02-16 10:57:36,125] Trial 2 finished with value: 2914812.948813081 and parameters: {'n_estimators': 1369, 'num_rounds': 353, 'learning_rate': 0.15717928239584564, 'num_leaves': 115, 'max_depth': 19, 'min_data_in_leaf': 712, 'lambda_l1': 0.008663796190634803, 'lambda_l2': 0.028305359158491, 'min_gain_to_split': 11.074712202921736, 'bagging_fraction': 0.5989717336485276, 'feature_fraction': 0.4658280476050427, 'early_stopping_rounds': 50}. Best is trial 1 with value: 2897145.494925644.
# [LightGBM] [Warning] lambda_l2 is set=0.006799522489381084, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.006799522489381084
# [LightGBM] [Warning] early_stopping_round is set=112, early_stopping_rounds=112 will be ignored. Current value: early_stopping_round=112
# [LightGBM] [Warning] bagging_fraction is set=0.3176795450973984, subsample=1.0 will be ignored. Current value: bagging_fraction=0.3176795450973984
# [LightGBM] [Warning] feature_fraction is set=0.5843935742256451, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5843935742256451
# [LightGBM] [Warning] min_data_in_leaf is set=241, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=241
# [LightGBM] [Warning] num_iterations is set=623, num_rounds=623 will be ignored. Current value: num_iterations=623
# [LightGBM] [Warning] min_gain_to_split is set=14.415205927321614, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=14.415205927321614
# [LightGBM] [Warning] lambda_l1 is set=0.043876236681442596, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.043876236681442596
# RMSE: 	 2939204.576340013
# [I 2023-02-16 10:57:36,903] Trial 3 finished with value: 2939204.576340013 and parameters: {'n_estimators': 238, 'num_rounds': 623, 'learning_rate': 0.03813564637239564, 'num_leaves': 71, 'max_depth': 28, 'min_data_in_leaf': 241, 'lambda_l1': 0.043876236681442596, 'lambda_l2': 0.006799522489381084, 'min_gain_to_split': 14.415205927321614, 'bagging_fraction': 0.3176795450973984, 'feature_fraction': 0.5843935742256451, 'early_stopping_rounds': 112}. Best is trial 1 with value: 2897145.494925644.
# [LightGBM] [Warning] lambda_l2 is set=7.050247818467554e-05, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.050247818467554e-05
# [LightGBM] [Warning] early_stopping_round is set=70, early_stopping_rounds=70 will be ignored. Current value: early_stopping_round=70
# [LightGBM] [Warning] bagging_fraction is set=0.500863798693426, subsample=1.0 will be ignored. Current value: bagging_fraction=0.500863798693426
# [LightGBM] [Warning] feature_fraction is set=0.3248901302592871, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3248901302592871
# [LightGBM] [Warning] min_data_in_leaf is set=955, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=955
# [LightGBM] [Warning] num_iterations is set=348, num_rounds=348 will be ignored. Current value: num_iterations=348
# [LightGBM] [Warning] min_gain_to_split is set=9.448522247757118, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=9.448522247757118
# [LightGBM] [Warning] lambda_l1 is set=0.03760736252467018, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.03760736252467018
# RMSE: 	 2262762.5233878125
# [I 2023-02-16 10:57:37,255] Trial 4 finished with value: 2262762.5233878125 and parameters: {'n_estimators': 1001, 'num_rounds': 348, 'learning_rate': 0.23496728796451083, 'num_leaves': 81, 'max_depth': 6, 'min_data_in_leaf': 955, 'lambda_l1': 0.03760736252467018, 'lambda_l2': 7.050247818467554e-05, 'min_gain_to_split': 9.448522247757118, 'bagging_fraction': 0.500863798693426, 'feature_fraction': 0.3248901302592871, 'early_stopping_rounds': 70}. Best is trial 4 with value: 2262762.5233878125.
# [LightGBM] [Warning] lambda_l2 is set=0.4854433153372959, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.4854433153372959
# [LightGBM] [Warning] early_stopping_round is set=82, early_stopping_rounds=82 will be ignored. Current value: early_stopping_round=82
# [LightGBM] [Warning] bagging_fraction is set=0.22350313502911756, subsample=1.0 will be ignored. Current value: bagging_fraction=0.22350313502911756
# [LightGBM] [Warning] feature_fraction is set=0.22156169421456584, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.22156169421456584
# [LightGBM] [Warning] min_data_in_leaf is set=655, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=655
# [LightGBM] [Warning] num_iterations is set=562, num_rounds=562 will be ignored. Current value: num_iterations=562
# [LightGBM] [Warning] min_gain_to_split is set=6.131721457600715, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=6.131721457600715
# [LightGBM] [Warning] lambda_l1 is set=0.00012710404031659575, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.00012710404031659575
# RMSE: 	 2938593.4180282336
# [I 2023-02-16 10:57:37,670] Trial 5 finished with value: 2938593.4180282336 and parameters: {'n_estimators': 396, 'num_rounds': 562, 'learning_rate': 0.18217168931285674, 'num_leaves': 54, 'max_depth': 28, 'min_data_in_leaf': 655, 'lambda_l1': 0.00012710404031659575, 'lambda_l2': 0.4854433153372959, 'min_gain_to_split': 6.131721457600715, 'bagging_fraction': 0.22350313502911756, 'feature_fraction': 0.22156169421456584, 'early_stopping_rounds': 82}. Best is trial 4 with value: 2262762.5233878125.
# [LightGBM] [Warning] lambda_l2 is set=0.5117855605035202, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5117855605035202
# [LightGBM] [Warning] early_stopping_round is set=154, early_stopping_rounds=154 will be ignored. Current value: early_stopping_round=154
# [LightGBM] [Warning] bagging_fraction is set=0.22679438873363258, subsample=1.0 will be ignored. Current value: bagging_fraction=0.22679438873363258
# [LightGBM] [Warning] feature_fraction is set=0.32474591443604534, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.32474591443604534
# [LightGBM] [Warning] min_data_in_leaf is set=277, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=277
# [LightGBM] [Warning] num_iterations is set=248, num_rounds=248 will be ignored. Current value: num_iterations=248
# [LightGBM] [Warning] min_gain_to_split is set=8.344094042123638, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=8.344094042123638
# [LightGBM] [Warning] lambda_l1 is set=2.212389447311988e-05, reg_alpha=0.0 will be ignored. Current value: lambda_l1=2.212389447311988e-05
# RMSE: 	 2861563.2789626704
# [I 2023-02-16 10:57:38,577] Trial 6 finished with value: 2861563.2789626704 and parameters: {'n_estimators': 290, 'num_rounds': 248, 'learning_rate': 0.029905329896676356, 'num_leaves': 244, 'max_depth': 19, 'min_data_in_leaf': 277, 'lambda_l1': 2.212389447311988e-05, 'lambda_l2': 0.5117855605035202, 'min_gain_to_split': 8.344094042123638, 'bagging_fraction': 0.22679438873363258, 'feature_fraction': 0.32474591443604534, 'early_stopping_rounds': 154}. Best is trial 4 with value: 2262762.5233878125.
# [LightGBM] [Warning] lambda_l2 is set=0.0019243468544563268, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.0019243468544563268
# [LightGBM] [Warning] early_stopping_round is set=192, early_stopping_rounds=192 will be ignored. Current value: early_stopping_round=192
# [LightGBM] [Warning] bagging_fraction is set=0.8086060963966876, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8086060963966876
# [LightGBM] [Warning] feature_fraction is set=0.8133151949226342, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8133151949226342
# [LightGBM] [Warning] min_data_in_leaf is set=215, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=215
# [LightGBM] [Warning] num_iterations is set=759, num_rounds=759 will be ignored. Current value: num_iterations=759
# [LightGBM] [Warning] min_gain_to_split is set=1.4937986260020435, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=1.4937986260020435
# [LightGBM] [Warning] lambda_l1 is set=4.03897885066682e-05, reg_alpha=0.0 will be ignored. Current value: lambda_l1=4.03897885066682e-05
# RMSE: 	 2873920.943264051
# [I 2023-02-16 10:57:39,450] Trial 7 finished with value: 2873920.943264051 and parameters: {'n_estimators': 376, 'num_rounds': 759, 'learning_rate': 0.2754776906956239, 'num_leaves': 194, 'max_depth': 8, 'min_data_in_leaf': 215, 'lambda_l1': 4.03897885066682e-05, 'lambda_l2': 0.0019243468544563268, 'min_gain_to_split': 1.4937986260020435, 'bagging_fraction': 0.8086060963966876, 'feature_fraction': 0.8133151949226342, 'early_stopping_rounds': 192}. Best is trial 4 with value: 2262762.5233878125.
# [LightGBM] [Warning] lambda_l2 is set=0.00010048190358816623, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.00010048190358816623
# [LightGBM] [Warning] early_stopping_round is set=198, early_stopping_rounds=198 will be ignored. Current value: early_stopping_round=198
# [LightGBM] [Warning] bagging_fraction is set=0.26977181612612955, subsample=1.0 will be ignored. Current value: bagging_fraction=0.26977181612612955
# [LightGBM] [Warning] feature_fraction is set=0.9534431151840834, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9534431151840834
# [LightGBM] [Warning] min_data_in_leaf is set=594, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=594
# [LightGBM] [Warning] num_iterations is set=831, num_rounds=831 will be ignored. Current value: num_iterations=831
# [LightGBM] [Warning] min_gain_to_split is set=11.574778200015151, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=11.574778200015151
# [LightGBM] [Warning] lambda_l1 is set=0.03743963966158385, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.03743963966158385
# RMSE: 	 2633103.675385704
# [I 2023-02-16 10:57:40,261] Trial 8 finished with value: 2633103.675385704 and parameters: {'n_estimators': 116, 'num_rounds': 831, 'learning_rate': 0.10799655928333741, 'num_leaves': 83, 'max_depth': 19, 'min_data_in_leaf': 594, 'lambda_l1': 0.03743963966158385, 'lambda_l2': 0.00010048190358816623, 'min_gain_to_split': 11.574778200015151, 'bagging_fraction': 0.26977181612612955, 'feature_fraction': 0.9534431151840834, 'early_stopping_rounds': 198}. Best is trial 4 with value: 2262762.5233878125.
# [LightGBM] [Warning] lambda_l2 is set=0.11289160215196857, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.11289160215196857
# [LightGBM] [Warning] early_stopping_round is set=115, early_stopping_rounds=115 will be ignored. Current value: early_stopping_round=115
# [LightGBM] [Warning] bagging_fraction is set=0.6674689681767234, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6674689681767234
# [LightGBM] [Warning] feature_fraction is set=0.42126135366592443, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.42126135366592443
# [LightGBM] [Warning] min_data_in_leaf is set=692, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=692
# [LightGBM] [Warning] num_iterations is set=861, num_rounds=861 will be ignored. Current value: num_iterations=861
# [LightGBM] [Warning] min_gain_to_split is set=1.167006778877977, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=1.167006778877977
# [LightGBM] [Warning] lambda_l1 is set=0.008689077482598577, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.008689077482598577
# RMSE: 	 2924597.8058945094
# [I 2023-02-16 10:57:40,730] Trial 9 finished with value: 2924597.8058945094 and parameters: {'n_estimators': 1928, 'num_rounds': 861, 'learning_rate': 0.11003961072574533, 'num_leaves': 111, 'max_depth': 6, 'min_data_in_leaf': 692, 'lambda_l1': 0.008689077482598577, 'lambda_l2': 0.11289160215196857, 'min_gain_to_split': 1.167006778877977, 'bagging_fraction': 0.6674689681767234, 'feature_fraction': 0.42126135366592443, 'early_stopping_rounds': 115}. Best is trial 4 with value: 2262762.5233878125.
# [LightGBM] [Warning] lambda_l2 is set=0.0003341277261566674, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.0003341277261566674
# [LightGBM] [Warning] early_stopping_round is set=65, early_stopping_rounds=65 will be ignored. Current value: early_stopping_round=65
# [LightGBM] [Warning] bagging_fraction is set=0.44343999976714665, subsample=1.0 will be ignored. Current value: bagging_fraction=0.44343999976714665
# [LightGBM] [Warning] feature_fraction is set=0.2816784190019945, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2816784190019945
# [LightGBM] [Warning] min_data_in_leaf is set=968, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=968
# [LightGBM] [Warning] num_iterations is set=195, num_rounds=195 will be ignored. Current value: num_iterations=195
# [LightGBM] [Warning] min_gain_to_split is set=6.970224630422194, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=6.970224630422194
# [LightGBM] [Warning] lambda_l1 is set=0.4250888468487456, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.4250888468487456
# RMSE: 	 2136435.8920544176
# [I 2023-02-16 10:57:41,051] Trial 10 finished with value: 2136435.8920544176 and parameters: {'n_estimators': 791, 'num_rounds': 195, 'learning_rate': 0.2968754418630168, 'num_leaves': 14, 'max_depth': 2, 'min_data_in_leaf': 968, 'lambda_l1': 0.4250888468487456, 'lambda_l2': 0.0003341277261566674, 'min_gain_to_split': 6.970224630422194, 'bagging_fraction': 0.44343999976714665, 'feature_fraction': 0.2816784190019945, 'early_stopping_rounds': 65}. Best is trial 10 with value: 2136435.8920544176.
# [LightGBM] [Warning] lambda_l2 is set=0.0002949056977412111, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.0002949056977412111
# [LightGBM] [Warning] early_stopping_round is set=50, early_stopping_rounds=50 will be ignored. Current value: early_stopping_round=50
# [LightGBM] [Warning] bagging_fraction is set=0.48788629121332844, subsample=1.0 will be ignored. Current value: bagging_fraction=0.48788629121332844
# [LightGBM] [Warning] feature_fraction is set=0.28074251714077597, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.28074251714077597
# [LightGBM] [Warning] min_data_in_leaf is set=943, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=943
# [LightGBM] [Warning] num_iterations is set=109, num_rounds=109 will be ignored. Current value: num_iterations=109
# [LightGBM] [Warning] min_gain_to_split is set=7.852482475794113, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=7.852482475794113
# [LightGBM] [Warning] lambda_l1 is set=0.7433634789524913, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.7433634789524913
# RMSE: 	 2939861.8061516066
# [I 2023-02-16 10:57:41,359] Trial 11 finished with value: 2939861.8061516066 and parameters: {'n_estimators': 775, 'num_rounds': 109, 'learning_rate': 0.2905556162263391, 'num_leaves': 11, 'max_depth': 2, 'min_data_in_leaf': 943, 'lambda_l1': 0.7433634789524913, 'lambda_l2': 0.0002949056977412111, 'min_gain_to_split': 7.852482475794113, 'bagging_fraction': 0.48788629121332844, 'feature_fraction': 0.28074251714077597, 'early_stopping_rounds': 50}. Best is trial 10 with value: 2136435.8920544176.
# [LightGBM] [Warning] lambda_l2 is set=1.630510526223479e-05, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.630510526223479e-05
# [LightGBM] [Warning] early_stopping_round is set=80, early_stopping_rounds=80 will be ignored. Current value: early_stopping_round=80
# [LightGBM] [Warning] bagging_fraction is set=0.40575591718739923, subsample=1.0 will be ignored. Current value: bagging_fraction=0.40575591718739923
# [LightGBM] [Warning] feature_fraction is set=0.21069822474587702, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.21069822474587702
# [LightGBM] [Warning] min_data_in_leaf is set=984, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=984
# [LightGBM] [Warning] num_iterations is set=363, num_rounds=363 will be ignored. Current value: num_iterations=363
# [LightGBM] [Warning] min_gain_to_split is set=5.730469008915655, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=5.730469008915655
# [LightGBM] [Warning] lambda_l1 is set=0.9858652998689145, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.9858652998689145
# RMSE: 	 2283992.2249941207
# [I 2023-02-16 10:57:41,702] Trial 12 finished with value: 2283992.2249941207 and parameters: {'n_estimators': 806, 'num_rounds': 363, 'learning_rate': 0.2422740259568021, 'num_leaves': 5, 'max_depth': 2, 'min_data_in_leaf': 984, 'lambda_l1': 0.9858652998689145, 'lambda_l2': 1.630510526223479e-05, 'min_gain_to_split': 5.730469008915655, 'bagging_fraction': 0.40575591718739923, 'feature_fraction': 0.21069822474587702, 'early_stopping_rounds': 80}. Best is trial 10 with value: 2136435.8920544176.
# [LightGBM] [Warning] lambda_l2 is set=0.00038817187947909755, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.00038817187947909755
# [LightGBM] [Warning] early_stopping_round is set=70, early_stopping_rounds=70 will be ignored. Current value: early_stopping_round=70
# [LightGBM] [Warning] bagging_fraction is set=0.43331228737891897, subsample=1.0 will be ignored. Current value: bagging_fraction=0.43331228737891897
# [LightGBM] [Warning] feature_fraction is set=0.3294850188157583, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3294850188157583
# [LightGBM] [Warning] min_data_in_leaf is set=823, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=823
# [LightGBM] [Warning] num_iterations is set=102, num_rounds=102 will be ignored. Current value: num_iterations=102
# [LightGBM] [Warning] min_gain_to_split is set=9.897881640258321, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=9.897881640258321
# [LightGBM] [Warning] lambda_l1 is set=0.13898312823437844, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.13898312823437844
# RMSE: 	 2075295.6236778996
# [I 2023-02-16 10:57:42,113] Trial 13 finished with value: 2075295.6236778996 and parameters: {'n_estimators': 1363, 'num_rounds': 102, 'learning_rate': 0.2992048437179327, 'num_leaves': 39, 'max_depth': 9, 'min_data_in_leaf': 823, 'lambda_l1': 0.13898312823437844, 'lambda_l2': 0.00038817187947909755, 'min_gain_to_split': 9.897881640258321, 'bagging_fraction': 0.43331228737891897, 'feature_fraction': 0.3294850188157583, 'early_stopping_rounds': 70}. Best is trial 13 with value: 2075295.6236778996.
# [LightGBM] [Warning] lambda_l2 is set=0.0007303514494968702, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.0007303514494968702
# [LightGBM] [Warning] early_stopping_round is set=95, early_stopping_rounds=95 will be ignored. Current value: early_stopping_round=95
# [LightGBM] [Warning] bagging_fraction is set=0.38466014933472487, subsample=1.0 will be ignored. Current value: bagging_fraction=0.38466014933472487
# [LightGBM] [Warning] feature_fraction is set=0.2666368031076897, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2666368031076897
# [LightGBM] [Warning] min_data_in_leaf is set=799, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=799
# [LightGBM] [Warning] num_iterations is set=135, num_rounds=135 will be ignored. Current value: num_iterations=135
# [LightGBM] [Warning] min_gain_to_split is set=5.253868240891245, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=5.253868240891245
# [LightGBM] [Warning] lambda_l1 is set=0.18126085020642385, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.18126085020642385
# RMSE: 	 2933868.954855098
# [I 2023-02-16 10:57:42,594] Trial 14 finished with value: 2933868.954855098 and parameters: {'n_estimators': 1408, 'num_rounds': 135, 'learning_rate': 0.2976875324212205, 'num_leaves': 41, 'max_depth': 11, 'min_data_in_leaf': 799, 'lambda_l1': 0.18126085020642385, 'lambda_l2': 0.0007303514494968702, 'min_gain_to_split': 5.253868240891245, 'bagging_fraction': 0.38466014933472487, 'feature_fraction': 0.2666368031076897, 'early_stopping_rounds': 95}. Best is trial 13 with value: 2075295.6236778996.
# [LightGBM] [Warning] lambda_l2 is set=0.000422314437386751, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.000422314437386751
# [LightGBM] [Warning] early_stopping_round is set=136, early_stopping_rounds=136 will be ignored. Current value: early_stopping_round=136
# [LightGBM] [Warning] bagging_fraction is set=0.35178543474042606, subsample=1.0 will be ignored. Current value: bagging_fraction=0.35178543474042606
# [LightGBM] [Warning] feature_fraction is set=0.364005049250905, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.364005049250905
# [LightGBM] [Warning] min_data_in_leaf is set=388, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=388
# [LightGBM] [Warning] num_iterations is set=993, num_rounds=993 will be ignored. Current value: num_iterations=993
# [LightGBM] [Warning] min_gain_to_split is set=9.761634729508033, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=9.761634729508033
# [LightGBM] [Warning] lambda_l1 is set=0.0016249475357268742, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0016249475357268742
# RMSE: 	 2920305.4778335295
# [I 2023-02-16 10:57:43,329] Trial 15 finished with value: 2920305.4778335295 and parameters: {'n_estimators': 1582, 'num_rounds': 993, 'learning_rate': 0.25848261688393476, 'num_leaves': 275, 'max_depth': 10, 'min_data_in_leaf': 388, 'lambda_l1': 0.0016249475357268742, 'lambda_l2': 0.000422314437386751, 'min_gain_to_split': 9.761634729508033, 'bagging_fraction': 0.35178543474042606, 'feature_fraction': 0.364005049250905, 'early_stopping_rounds': 136}. Best is trial 13 with value: 2075295.6236778996.
# [LightGBM] [Warning] lambda_l2 is set=0.0029088358480393634, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.0029088358480393634
# [LightGBM] [Warning] early_stopping_round is set=63, early_stopping_rounds=63 will be ignored. Current value: early_stopping_round=63
# [LightGBM] [Warning] bagging_fraction is set=0.4721190191360439, subsample=1.0 will be ignored. Current value: bagging_fraction=0.4721190191360439
# [LightGBM] [Warning] feature_fraction is set=0.38968875380474594, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.38968875380474594
# [LightGBM] [Warning] min_data_in_leaf is set=812, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=812
# [LightGBM] [Warning] num_iterations is set=219, num_rounds=219 will be ignored. Current value: num_iterations=219
# [LightGBM] [Warning] min_gain_to_split is set=4.0407915956579705, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=4.0407915956579705
# [LightGBM] [Warning] lambda_l1 is set=0.21893526405900546, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.21893526405900546
# RMSE: 	 2917720.5121041522
# [I 2023-02-16 10:57:43,729] Trial 16 finished with value: 2917720.5121041522 and parameters: {'n_estimators': 722, 'num_rounds': 219, 'learning_rate': 0.29726615568773235, 'num_leaves': 31, 'max_depth': 15, 'min_data_in_leaf': 812, 'lambda_l1': 0.21893526405900546, 'lambda_l2': 0.0029088358480393634, 'min_gain_to_split': 4.0407915956579705, 'bagging_fraction': 0.4721190191360439, 'feature_fraction': 0.38968875380474594, 'early_stopping_rounds': 63}. Best is trial 13 with value: 2075295.6236778996.
# [LightGBM] [Warning] lambda_l2 is set=0.00014589420237809763, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.00014589420237809763
# [LightGBM] [Warning] early_stopping_round is set=102, early_stopping_rounds=102 will be ignored. Current value: early_stopping_round=102
# [LightGBM] [Warning] bagging_fraction is set=0.32028220708593147, subsample=1.0 will be ignored. Current value: bagging_fraction=0.32028220708593147
# [LightGBM] [Warning] feature_fraction is set=0.258506083268487, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.258506083268487
# [LightGBM] [Warning] min_data_in_leaf is set=855, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=855
# [LightGBM] [Warning] num_iterations is set=232, num_rounds=232 will be ignored. Current value: num_iterations=232
# [LightGBM] [Warning] min_gain_to_split is set=7.497983679210176, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=7.497983679210176
# [LightGBM] [Warning] lambda_l1 is set=0.0014367005603590063, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0014367005603590063
# RMSE: 	 2938445.4011844285
# [I 2023-02-16 10:57:44,542] Trial 17 finished with value: 2938445.4011844285 and parameters: {'n_estimators': 1150, 'num_rounds': 232, 'learning_rate': 0.20448895815154802, 'num_leaves': 119, 'max_depth': 5, 'min_data_in_leaf': 855, 'lambda_l1': 0.0014367005603590063, 'lambda_l2': 0.00014589420237809763, 'min_gain_to_split': 7.497983679210176, 'bagging_fraction': 0.32028220708593147, 'feature_fraction': 0.258506083268487, 'early_stopping_rounds': 102}. Best is trial 13 with value: 2075295.6236778996.
# [LightGBM] [Warning] lambda_l2 is set=0.0010494654912449701, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.0010494654912449701
# [LightGBM] [Warning] early_stopping_round is set=131, early_stopping_rounds=131 will be ignored. Current value: early_stopping_round=131
# [LightGBM] [Warning] bagging_fraction is set=0.5558397301864352, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5558397301864352
# [LightGBM] [Warning] feature_fraction is set=0.31094310209964804, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.31094310209964804
# [LightGBM] [Warning] min_data_in_leaf is set=436, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=436
# [LightGBM] [Warning] num_iterations is set=494, num_rounds=494 will be ignored. Current value: num_iterations=494
# [LightGBM] [Warning] min_gain_to_split is set=9.934436116360637, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=9.934436116360637
# [LightGBM] [Warning] lambda_l1 is set=0.1457079599715316, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1457079599715316
# RMSE: 	 2218173.152251174
# [I 2023-02-16 10:57:44,967] Trial 18 finished with value: 2218173.152251174 and parameters: {'n_estimators': 1651, 'num_rounds': 494, 'learning_rate': 0.2567091612673537, 'num_leaves': 7, 'max_depth': 4, 'min_data_in_leaf': 436, 'lambda_l1': 0.1457079599715316, 'lambda_l2': 0.0010494654912449701, 'min_gain_to_split': 9.934436116360637, 'bagging_fraction': 0.5558397301864352, 'feature_fraction': 0.31094310209964804, 'early_stopping_rounds': 131}. Best is trial 13 with value: 2075295.6236778996.
# [LightGBM] [Warning] lambda_l2 is set=0.0038914322508688043, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.0038914322508688043
# [LightGBM] [Warning] early_stopping_round is set=66, early_stopping_rounds=66 will be ignored. Current value: early_stopping_round=66
# [LightGBM] [Warning] bagging_fraction is set=0.43575288657118905, subsample=1.0 will be ignored. Current value: bagging_fraction=0.43575288657118905
# [LightGBM] [Warning] feature_fraction is set=0.23825040798774985, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.23825040798774985
# [LightGBM] [Warning] min_data_in_leaf is set=19, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=19
# [LightGBM] [Warning] num_iterations is set=444, num_rounds=444 will be ignored. Current value: num_iterations=444
# [LightGBM] [Warning] min_gain_to_split is set=14.657597816238138, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=14.657597816238138
# [LightGBM] [Warning] lambda_l1 is set=0.5984521544221019, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.5984521544221019
# RMSE: 	 2933648.941134331
# [I 2023-02-16 10:57:45,946] Trial 19 finished with value: 2933648.941134331 and parameters: {'n_estimators': 566, 'num_rounds': 444, 'learning_rate': 0.2656739264236708, 'num_leaves': 152, 'max_depth': 9, 'min_data_in_leaf': 19, 'lambda_l1': 0.5984521544221019, 'lambda_l2': 0.0038914322508688043, 'min_gain_to_split': 14.657597816238138, 'bagging_fraction': 0.43575288657118905, 'feature_fraction': 0.23825040798774985, 'early_stopping_rounds': 66}. Best is trial 13 with value: 2075295.6236778996.
# [LightGBM] [Warning] lambda_l2 is set=0.0002925268660720654, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.0002925268660720654
# [LightGBM] [Warning] early_stopping_round is set=103, early_stopping_rounds=103 will be ignored. Current value: early_stopping_round=103
# [LightGBM] [Warning] bagging_fraction is set=0.4119084840549111, subsample=1.0 will be ignored. Current value: bagging_fraction=0.4119084840549111
# [LightGBM] [Warning] feature_fraction is set=0.3621175673683003, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3621175673683003
# [LightGBM] [Warning] min_data_in_leaf is set=872, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=872
# [LightGBM] [Warning] num_iterations is set=184, num_rounds=184 will be ignored. Current value: num_iterations=184
# [LightGBM] [Warning] min_gain_to_split is set=4.149912361838046, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=4.149912361838046
# [LightGBM] [Warning] lambda_l1 is set=0.11882696053097146, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.11882696053097146
# RMSE: 	 2926065.4073281433
# [I 2023-02-16 10:57:46,425] Trial 20 finished with value: 2926065.4073281433 and parameters: {'n_estimators': 974, 'num_rounds': 184, 'learning_rate': 0.21403173083076907, 'num_leaves': 42, 'max_depth': 13, 'min_data_in_leaf': 872, 'lambda_l1': 0.11882696053097146, 'lambda_l2': 0.0002925268660720654, 'min_gain_to_split': 4.149912361838046, 'bagging_fraction': 0.4119084840549111, 'feature_fraction': 0.3621175673683003, 'early_stopping_rounds': 103}. Best is trial 13 with value: 2075295.6236778996.
# [LightGBM] [Warning] lambda_l2 is set=0.0009534795916181162, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.0009534795916181162
# [LightGBM] [Warning] early_stopping_round is set=137, early_stopping_rounds=137 will be ignored. Current value: early_stopping_round=137
# [LightGBM] [Warning] bagging_fraction is set=0.5534130307091182, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5534130307091182
# [LightGBM] [Warning] feature_fraction is set=0.3050988624338056, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3050988624338056
# [LightGBM] [Warning] min_data_in_leaf is set=414, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=414
# [LightGBM] [Warning] num_iterations is set=281, num_rounds=281 will be ignored. Current value: num_iterations=281
# [LightGBM] [Warning] min_gain_to_split is set=9.975637425990568, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=9.975637425990568
# [LightGBM] [Warning] lambda_l1 is set=0.09583770875291035, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.09583770875291035
# RMSE: 	 2394417.768520895
# [I 2023-02-16 10:57:46,776] Trial 21 finished with value: 2394417.768520895 and parameters: {'n_estimators': 1589, 'num_rounds': 281, 'learning_rate': 0.26375517185617714, 'num_leaves': 2, 'max_depth': 4, 'min_data_in_leaf': 414, 'lambda_l1': 0.09583770875291035, 'lambda_l2': 0.0009534795916181162, 'min_gain_to_split': 9.975637425990568, 'bagging_fraction': 0.5534130307091182, 'feature_fraction': 0.3050988624338056, 'early_stopping_rounds': 137}. Best is trial 13 with value: 2075295.6236778996.
# [LightGBM] [Warning] lambda_l2 is set=0.0008249291576257626, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.0008249291576257626
# [LightGBM] [Warning] early_stopping_round is set=136, early_stopping_rounds=136 will be ignored. Current value: early_stopping_round=136
# [LightGBM] [Warning] bagging_fraction is set=0.5617100412124201, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5617100412124201
# [LightGBM] [Warning] feature_fraction is set=0.2932534353404174, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2932534353404174
# [LightGBM] [Warning] min_data_in_leaf is set=463, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=463
# [LightGBM] [Warning] num_iterations is set=104, num_rounds=104 will be ignored. Current value: num_iterations=104
# [LightGBM] [Warning] min_gain_to_split is set=8.30550266084667, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=8.30550266084667
# [LightGBM] [Warning] lambda_l1 is set=0.513338878109594, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.513338878109594
# RMSE: 	 2132262.9191824314
# [I 2023-02-16 10:57:47,134] Trial 22 finished with value: 2132262.9191824314 and parameters: {'n_estimators': 1638, 'num_rounds': 104, 'learning_rate': 0.29842622853867795, 'num_leaves': 27, 'max_depth': 2, 'min_data_in_leaf': 463, 'lambda_l1': 0.513338878109594, 'lambda_l2': 0.0008249291576257626, 'min_gain_to_split': 8.30550266084667, 'bagging_fraction': 0.5617100412124201, 'feature_fraction': 0.2932534353404174, 'early_stopping_rounds': 136}. Best is trial 13 with value: 2075295.6236778996.
# [LightGBM] [Warning] lambda_l2 is set=4.7447610037864545e-05, reg_lambda=0.0 will be ignored. Current value: lambda_l2=4.7447610037864545e-05
# [LightGBM] [Warning] early_stopping_round is set=156, early_stopping_rounds=156 will be ignored. Current value: early_stopping_round=156
# [LightGBM] [Warning] bagging_fraction is set=0.45959692646559924, subsample=1.0 will be ignored. Current value: bagging_fraction=0.45959692646559924
# [LightGBM] [Warning] feature_fraction is set=0.2432278182258814, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2432278182258814
# [LightGBM] [Warning] min_data_in_leaf is set=770, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=770
# [LightGBM] [Warning] num_iterations is set=102, num_rounds=102 will be ignored. Current value: num_iterations=102
# [LightGBM] [Warning] min_gain_to_split is set=7.083684825738944, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=7.083684825738944
# [LightGBM] [Warning] lambda_l1 is set=0.4746051977484975, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.4746051977484975
# RMSE: 	 2942168.252196057
# [I 2023-02-16 10:57:47,487] Trial 23 finished with value: 2942168.252196057 and parameters: {'n_estimators': 1327, 'num_rounds': 102, 'learning_rate': 0.28250793504952454, 'num_leaves': 55, 'max_depth': 2, 'min_data_in_leaf': 770, 'lambda_l1': 0.4746051977484975, 'lambda_l2': 4.7447610037864545e-05, 'min_gain_to_split': 7.083684825738944, 'bagging_fraction': 0.45959692646559924, 'feature_fraction': 0.2432278182258814, 'early_stopping_rounds': 156}. Best is trial 13 with value: 2075295.6236778996.
# [LightGBM] [Warning] lambda_l2 is set=0.0001975749682172259, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.0001975749682172259
# [LightGBM] [Warning] early_stopping_round is set=175, early_stopping_rounds=175 will be ignored. Current value: early_stopping_round=175
# [LightGBM] [Warning] bagging_fraction is set=0.5324367944859827, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5324367944859827
# [LightGBM] [Warning] feature_fraction is set=0.2816635993830326, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2816635993830326
# [LightGBM] [Warning] min_data_in_leaf is set=495, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=495
# [LightGBM] [Warning] num_iterations is set=179, num_rounds=179 will be ignored. Current value: num_iterations=179
# [LightGBM] [Warning] min_gain_to_split is set=8.76901660012941, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=8.76901660012941
# [LightGBM] [Warning] lambda_l1 is set=0.3937830343717315, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.3937830343717315
# RMSE: 	 2069075.70197481
# [I 2023-02-16 10:57:48,165] Trial 24 finished with value: 2069075.70197481 and parameters: {'n_estimators': 1764, 'num_rounds': 179, 'learning_rate': 0.2998108432944565, 'num_leaves': 29, 'max_depth': 7, 'min_data_in_leaf': 495, 'lambda_l1': 0.3937830343717315, 'lambda_l2': 0.0001975749682172259, 'min_gain_to_split': 8.76901660012941, 'bagging_fraction': 0.5324367944859827, 'feature_fraction': 0.2816635993830326, 'early_stopping_rounds': 175}. Best is trial 24 with value: 2069075.70197481.
# [LightGBM] [Warning] lambda_l2 is set=0.0001262960704196454, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.0001262960704196454
# [LightGBM] [Warning] early_stopping_round is set=185, early_stopping_rounds=185 will be ignored. Current value: early_stopping_round=185
# [LightGBM] [Warning] bagging_fraction is set=0.5336853512658398, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5336853512658398
# [LightGBM] [Warning] feature_fraction is set=0.201503378287706, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.201503378287706
# [LightGBM] [Warning] min_data_in_leaf is set=509, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=509
# [LightGBM] [Warning] num_iterations is set=287, num_rounds=287 will be ignored. Current value: num_iterations=287
# [LightGBM] [Warning] min_gain_to_split is set=8.631529401992978, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=8.631529401992978
# [LightGBM] [Warning] lambda_l1 is set=0.372684935107913, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.372684935107913
# RMSE: 	 2218040.940115389
# [I 2023-02-16 10:57:48,884] Trial 25 finished with value: 2218040.940115389 and parameters: {'n_estimators': 1761, 'num_rounds': 287, 'learning_rate': 0.24902626527043553, 'num_leaves': 102, 'max_depth': 7, 'min_data_in_leaf': 509, 'lambda_l1': 0.372684935107913, 'lambda_l2': 0.0001262960704196454, 'min_gain_to_split': 8.631529401992978, 'bagging_fraction': 0.5336853512658398, 'feature_fraction': 0.201503378287706, 'early_stopping_rounds': 185}. Best is trial 24 with value: 2069075.70197481.
# [LightGBM] [Warning] lambda_l2 is set=1.3896526565909394e-05, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.3896526565909394e-05
# [LightGBM] [Warning] early_stopping_round is set=174, early_stopping_rounds=174 will be ignored. Current value: early_stopping_round=174
# [LightGBM] [Warning] bagging_fraction is set=0.6139626883671059, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6139626883671059
# [LightGBM] [Warning] feature_fraction is set=0.23730443334633233, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.23730443334633233
# [LightGBM] [Warning] min_data_in_leaf is set=349, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=349
# [LightGBM] [Warning] num_iterations is set=141, num_rounds=141 will be ignored. Current value: num_iterations=141
# [LightGBM] [Warning] min_gain_to_split is set=8.593172489697018, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=8.593172489697018
# [LightGBM] [Warning] lambda_l1 is set=0.07941647608384118, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.07941647608384118
# RMSE: 	 2934066.484383773
# [I 2023-02-16 10:57:49,603] Trial 26 finished with value: 2934066.484383773 and parameters: {'n_estimators': 1760, 'num_rounds': 141, 'learning_rate': 0.2723862580649905, 'num_leaves': 33, 'max_depth': 12, 'min_data_in_leaf': 349, 'lambda_l1': 0.07941647608384118, 'lambda_l2': 1.3896526565909394e-05, 'min_gain_to_split': 8.593172489697018, 'bagging_fraction': 0.6139626883671059, 'feature_fraction': 0.23730443334633233, 'early_stopping_rounds': 174}. Best is trial 24 with value: 2069075.70197481.
# [LightGBM] [Warning] lambda_l2 is set=4.619620273834019e-05, reg_lambda=0.0 will be ignored. Current value: lambda_l2=4.619620273834019e-05
# [LightGBM] [Warning] early_stopping_round is set=149, early_stopping_rounds=149 will be ignored. Current value: early_stopping_round=149
# [LightGBM] [Warning] bagging_fraction is set=0.706622799021382, subsample=1.0 will be ignored. Current value: bagging_fraction=0.706622799021382
# [LightGBM] [Warning] feature_fraction is set=0.3537051378139144, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3537051378139144
# [LightGBM] [Warning] min_data_in_leaf is set=479, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=479
# [LightGBM] [Warning] num_iterations is set=399, num_rounds=399 will be ignored. Current value: num_iterations=399
# [LightGBM] [Warning] min_gain_to_split is set=11.014968987568642, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=11.014968987568642
# [LightGBM] [Warning] lambda_l1 is set=0.9796272159655355, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.9796272159655355
# RMSE: 	 2923657.004330461
# [I 2023-02-16 10:57:50,348] Trial 27 finished with value: 2923657.004330461 and parameters: {'n_estimators': 1495, 'num_rounds': 399, 'learning_rate': 0.24054386577547143, 'num_leaves': 62, 'max_depth': 15, 'min_data_in_leaf': 479, 'lambda_l1': 0.9796272159655355, 'lambda_l2': 4.619620273834019e-05, 'min_gain_to_split': 11.014968987568642, 'bagging_fraction': 0.706622799021382, 'feature_fraction': 0.3537051378139144, 'early_stopping_rounds': 149}. Best is trial 24 with value: 2069075.70197481.
# [LightGBM] [Warning] lambda_l2 is set=0.00017901729685488183, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.00017901729685488183
# [LightGBM] [Warning] early_stopping_round is set=174, early_stopping_rounds=174 will be ignored. Current value: early_stopping_round=174
# [LightGBM] [Warning] bagging_fraction is set=0.5320796603879218, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5320796603879218
# [LightGBM] [Warning] feature_fraction is set=0.28789223048291007, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.28789223048291007
# [LightGBM] [Warning] min_data_in_leaf is set=582, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=582
# [LightGBM] [Warning] num_iterations is set=164, num_rounds=164 will be ignored. Current value: num_iterations=164
# [LightGBM] [Warning] min_gain_to_split is set=12.16330399225322, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=12.16330399225322
# [LightGBM] [Warning] lambda_l1 is set=0.2975871146260838, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.2975871146260838
# RMSE: 	 2135044.685484248
# [I 2023-02-16 10:57:51,065] Trial 28 finished with value: 2135044.685484248 and parameters: {'n_estimators': 1768, 'num_rounds': 164, 'learning_rate': 0.2780742839473798, 'num_leaves': 90, 'max_depth': 8, 'min_data_in_leaf': 582, 'lambda_l1': 0.2975871146260838, 'lambda_l2': 0.00017901729685488183, 'min_gain_to_split': 12.16330399225322, 'bagging_fraction': 0.5320796603879218, 'feature_fraction': 0.28789223048291007, 'early_stopping_rounds': 174}. Best is trial 24 with value: 2069075.70197481.
# [LightGBM] [Warning] lambda_l2 is set=0.0006595663271547758, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.0006595663271547758
# [LightGBM] [Warning] early_stopping_round is set=117, early_stopping_rounds=117 will be ignored. Current value: early_stopping_round=117
# [LightGBM] [Warning] bagging_fraction is set=0.6368191537313033, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6368191537313033
# [LightGBM] [Warning] feature_fraction is set=0.2627927944979756, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2627927944979756
# ...
# RMSE: 	 2930147.1181973773
# [I 2023-02-16 10:58:08,844] Trial 48 finished with value: 2930147.1181973773 and parameters: {'n_estimators': 1371, 'num_rounds': 257, 'learning_rate': 0.2992904406746189, 'num_leaves': 135, 'max_depth': 27, 'min_data_in_leaf': 87, 'lambda_l1': 0.004671908519947422, 'lambda_l2': 8.403298158370916e-05, 'min_gain_to_split': 12.408503033414325, 'bagging_fraction': 0.4869070594933258, 'feature_fraction': 0.2604286212566334, 'early_stopping_rounds': 59}. Best is trial 24 with value: 2069075.70197481.
# [LightGBM] [Warning] lambda_l2 is set=0.0001309373704379914, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.0001309373704379914
# [LightGBM] [Warning] early_stopping_round is set=74, early_stopping_rounds=74 will be ignored. Current value: early_stopping_round=74
# [LightGBM] [Warning] bagging_fraction is set=0.591403613377693, subsample=1.0 will be ignored. Current value: bagging_fraction=0.591403613377693
# [LightGBM] [Warning] feature_fraction is set=0.31588068832821825, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.31588068832821825
# [LightGBM] [Warning] min_data_in_leaf is set=708, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=708
# [LightGBM] [Warning] num_iterations is set=212, num_rounds=212 will be ignored. Current value: num_iterations=212
# [LightGBM] [Warning] min_gain_to_split is set=11.589242621319615, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=11.589242621319615
# [LightGBM] [Warning] lambda_l1 is set=0.24615128954940912, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.24615128954940912
# RMSE: 	 2413281.6112079504
# [I 2023-02-16 10:58:09,284] Trial 49 finished with value: 2413281.6112079504 and parameters: {'n_estimators': 640, 'num_rounds': 212, 'learning_rate': 0.18346039948232118, 'num_leaves': 17, 'max_depth': 21, 'min_data_in_leaf': 708, 'lambda_l1': 0.24615128954940912, 'lambda_l2': 0.0001309373704379914, 'min_gain_to_split': 11.589242621319615, 'bagging_fraction': 0.591403613377693, 'feature_fraction': 0.31588068832821825, 'early_stopping_rounds': 74}. Best is trial 24 with value: 2069075.70197481.
# [LightGBM] [Warning] lambda_l2 is set=1.0383297734664905e-05, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0383297734664905e-05
# [LightGBM] [Warning] early_stopping_round is set=97, early_stopping_rounds=97 will be ignored. Current value: early_stopping_round=97
# [LightGBM] [Warning] bagging_fraction is set=0.49946764811858335, subsample=1.0 will be ignored. Current value: bagging_fraction=0.49946764811858335
# [LightGBM] [Warning] feature_fraction is set=0.285958256000677, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.285958256000677
# [LightGBM] [Warning] min_data_in_leaf is set=264, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=264
# [LightGBM] [Warning] num_iterations is set=125, num_rounds=125 will be ignored. Current value: num_iterations=125
# [LightGBM] [Warning] min_gain_to_split is set=9.295963959217993, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=9.295963959217993
# [LightGBM] [Warning] lambda_l1 is set=0.1443308811274915, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1443308811274915
# RMSE: 	 2158597.6208763085
# [I 2023-02-16 10:58:10,003] Trial 50 finished with value: 2158597.6208763085 and parameters: {'n_estimators': 444, 'num_rounds': 125, 'learning_rate': 0.2689794340595631, 'num_leaves': 55, 'max_depth': 30, 'min_data_in_leaf': 264, 'lambda_l1': 0.1443308811274915, 'lambda_l2': 1.0383297734664905e-05, 'min_gain_to_split': 9.295963959217993, 'bagging_fraction': 0.49946764811858335, 'feature_fraction': 0.285958256000677, 'early_stopping_rounds': 97}. Best is trial 24 with value: 2069075.70197481.
# [LightGBM] [Warning] lambda_l2 is set=2.5676663965596784e-05, reg_lambda=0.0 will be ignored. Current value: lambda_l2=2.5676663965596784e-05
# [LightGBM] [Warning] early_stopping_round is set=87, early_stopping_rounds=87 will be ignored. Current value: early_stopping_round=87
# [LightGBM] [Warning] bagging_fraction is set=0.7744670987584795, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7744670987584795
# [LightGBM] [Warning] feature_fraction is set=0.349751217370846, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.349751217370846
# [LightGBM] [Warning] min_data_in_leaf is set=88, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=88
# [LightGBM] [Warning] num_iterations is set=149, num_rounds=149 will be ignored. Current value: num_iterations=149
# [LightGBM] [Warning] min_gain_to_split is set=13.428655372584435, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=13.428655372584435
# [LightGBM] [Warning] lambda_l1 is set=0.024027854025464927, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.024027854025464927
# RMSE: 	 2916769.7619608496
# [I 2023-02-16 10:58:10,635] Trial 51 finished with value: 2916769.7619608496 and parameters: {'n_estimators': 867, 'num_rounds': 149, 'learning_rate': 0.2841890824900208, 'num_leaves': 39, 'max_depth': 27, 'min_data_in_leaf': 88, 'lambda_l1': 0.024027854025464927, 'lambda_l2': 2.5676663965596784e-05, 'min_gain_to_split': 13.428655372584435, 'bagging_fraction': 0.7744670987584795, 'feature_fraction': 0.349751217370846, 'early_stopping_rounds': 87}. Best is trial 24 with value: 2069075.70197481.
# [LightGBM] [Warning] lambda_l2 is set=3.286404529111098e-05, reg_lambda=0.0 will be ignored. Current value: lambda_l2=3.286404529111098e-05
# [LightGBM] [Warning] early_stopping_round is set=123, early_stopping_rounds=123 will be ignored. Current value: early_stopping_round=123
# [LightGBM] [Warning] bagging_fraction is set=0.6983578150116349, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6983578150116349
# [LightGBM] [Warning] feature_fraction is set=0.3209257176831226, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3209257176831226
# [LightGBM] [Warning] min_data_in_leaf is set=166, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=166
# [LightGBM] [Warning] num_iterations is set=164, num_rounds=164 will be ignored. Current value: num_iterations=164
# [LightGBM] [Warning] min_gain_to_split is set=14.188140825726467, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=14.188140825726467
# [LightGBM] [Warning] lambda_l1 is set=0.041416282533489494, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.041416282533489494
# RMSE: 	 2099592.0324875326
# [I 2023-02-16 10:58:11,494] Trial 52 finished with value: 2099592.0324875326 and parameters: {'n_estimators': 1014, 'num_rounds': 164, 'learning_rate': 0.28910467924765976, 'num_leaves': 49, 'max_depth': 26, 'min_data_in_leaf': 166, 'lambda_l1': 0.041416282533489494, 'lambda_l2': 3.286404529111098e-05, 'min_gain_to_split': 14.188140825726467, 'bagging_fraction': 0.6983578150116349, 'feature_fraction': 0.3209257176831226, 'early_stopping_rounds': 123}. Best is trial 24 with value: 2069075.70197481.
# [LightGBM] [Warning] lambda_l2 is set=6.292977025860598e-05, reg_lambda=0.0 will be ignored. Current value: lambda_l2=6.292977025860598e-05
# [LightGBM] [Warning] early_stopping_round is set=122, early_stopping_rounds=122 will be ignored. Current value: early_stopping_round=122
# [LightGBM] [Warning] bagging_fraction is set=0.6808192824801973, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6808192824801973
# [LightGBM] [Warning] feature_fraction is set=0.30859570222402855, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.30859570222402855
# [LightGBM] [Warning] min_data_in_leaf is set=171, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=171
# [LightGBM] [Warning] num_iterations is set=206, num_rounds=206 will be ignored. Current value: num_iterations=206
# [LightGBM] [Warning] min_gain_to_split is set=14.00760994783045, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=14.00760994783045
# [LightGBM] [Warning] lambda_l1 is set=0.049308878189232276, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.049308878189232276
# RMSE: 	 2106888.1340639167
# [I 2023-02-16 10:58:12,720] Trial 53 finished with value: 2106888.1340639167 and parameters: {'n_estimators': 983, 'num_rounds': 206, 'learning_rate': 0.288722487698842, 'num_leaves': 15, 'max_depth': 29, 'min_data_in_leaf': 171, 'lambda_l1': 0.049308878189232276, 'lambda_l2': 6.292977025860598e-05, 'min_gain_to_split': 14.00760994783045, 'bagging_fraction': 0.6808192824801973, 'feature_fraction': 0.30859570222402855, 'early_stopping_rounds': 122}. Best is trial 24 with value: 2069075.70197481.
# [LightGBM] [Warning] lambda_l2 is set=9.10780894169107e-05, reg_lambda=0.0 will be ignored. Current value: lambda_l2=9.10780894169107e-05
# [LightGBM] [Warning] early_stopping_round is set=120, early_stopping_rounds=120 will be ignored. Current value: early_stopping_round=120
# [LightGBM] [Warning] bagging_fraction is set=0.691209217620959, subsample=1.0 will be ignored. Current value: bagging_fraction=0.691209217620959
# [LightGBM] [Warning] feature_fraction is set=0.27223489335727385, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.27223489335727385
# [LightGBM] [Warning] min_data_in_leaf is set=137, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=137
# [LightGBM] [Warning] num_iterations is set=101, num_rounds=101 will be ignored. Current value: num_iterations=101
# [LightGBM] [Warning] min_gain_to_split is set=14.561159864935792, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=14.561159864935792
# [LightGBM] [Warning] lambda_l1 is set=0.0562007257691068, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0562007257691068
# [W 2023-02-16 10:58:12,980] Trial 54 failed with parameters: {'n_estimators': 1014, 'num_rounds': 101, 'learning_rate': 0.290465957727822, 'num_leaves': 6, 'max_depth': 30, 'min_data_in_leaf': 137, 'lambda_l1': 0.0562007257691068, 'lambda_l2': 9.10780894169107e-05, 'min_gain_to_split': 14.561159864935792, 'bagging_fraction': 0.691209217620959, 'feature_fraction': 0.27223489335727385, 'early_stopping_rounds': 120} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/optuna/study/_optimize.py", line 200, in _run_trial
#     value_or_values = func(trial)
#   File "/tmp/ipykernel_24/1403805610.py", line 2, in <lambda>
#     func = lambda trial: objective_lgbm(trial, f_X, f_y, X_val, y_val)
#   File "/tmp/ipykernel_24/2754529647.py", line 26, in objective_lgbm
#     verbose=-1,
#   File "/opt/conda/lib/python3.7/site-packages/lightgbm/sklearn.py", line 899, in fit
#     categorical_feature=categorical_feature, callbacks=callbacks, init_model=init_model)
#   File "/opt/conda/lib/python3.7/site-packages/lightgbm/sklearn.py", line 758, in fit
#     callbacks=callbacks
#   File "/opt/conda/lib/python3.7/site-packages/lightgbm/engine.py", line 292, in train
#     booster.update(fobj=fobj)
#   File "/opt/conda/lib/python3.7/site-packages/lightgbm/basic.py", line 3023, in update
#     ctypes.byref(is_finished)))
# KeyboardInterrupt
# [W 2023-02-16 10:58:12,982] Trial 54 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_24/1403805610.py in <module>
#       1 study_lgbm = optuna.create_study(direction="minimize", study_name="LGBM Tuning")
#       2 func = lambda trial: objective_lgbm(trial, f_X, f_y, X_val, y_val)
# ----> 3 study_lgbm.optimize(func, n_trials=100, show_progress_bar=True)
#
# /opt/conda/lib/python3.7/site-packages/optuna/study/study.py in optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     432             callbacks=callbacks,
#     433             gc_after_trial=gc_after_trial,
# --> 434             show_progress_bar=show_progress_bar,
#     435         )
#     436
#
# /opt/conda/lib/python3.7/site-packages/optuna/study/_optimize.py in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      74                 reseed_sampler_rng=False,
#      75                 time_start=None,
# ---> 76                 progress_bar=progress_bar,
#      77             )
#      78         else:
#
# /opt/conda/lib/python3.7/site-packages/optuna/study/_optimize.py in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     161
#     162         try:
# --> 163             frozen_trial = _run_trial(study, func, catch)
#     164         finally:
#     165             # The following line mitigates memory problems that can be occurred in some
#
# /opt/conda/lib/python3.7/site-packages/optuna/study/_optimize.py in _run_trial(study, func, catch)
#     249         and not isinstance(func_err, catch)
#     250     ):
# --> 251         raise func_err
#     252     return frozen_trial
#     253
#
# /opt/conda/lib/python3.7/site-packages/optuna/study/_optimize.py in _run_trial(study, func, catch)
#     198     with get_heartbeat_thread(trial._trial_id, study._storage):
#     199         try:
# --> 200             value_or_values = func(trial)
#     201         except exceptions.TrialPruned as e:
#     202             # TODO(mamu): Handle multi-objective cases.
#
# /tmp/ipykernel_24/1403805610.py in <lambda>(trial)
#       1 study_lgbm = optuna.create_study(direction="minimize", study_name="LGBM Tuning")
# ----> 2 func = lambda trial: objective_lgbm(trial, f_X, f_y, X_val, y_val)
#       3 study_lgbm.optimize(func, n_trials=100, show_progress_bar=True)
#
# /tmp/ipykernel_24/2754529647.py in objective_lgbm(trial, f_X, f_y, X_val, y_val)
#      24         eval_set=[(X_val, y_val)],
#      25         eval_metric="auc",
# ---> 26         verbose=-1,
#      27     )
#      28     y_preds = model.predict(X_val)
#
# /opt/conda/lib/python3.7/site-packages/lightgbm/sklearn.py in fit(self, X, y, sample_weight, init_score, eval_set, eval_names, eval_sample_weight, eval_init_score, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks, init_model)
#     897                     eval_init_score=eval_init_score, eval_metric=eval_metric,
#     898                     early_stopping_rounds=early_stopping_rounds, verbose=verbose, feature_name=feature_name,
# --> 899                     categorical_feature=categorical_feature, callbacks=callbacks, init_model=init_model)
#     900         return self
#     901
#
# /opt/conda/lib/python3.7/site-packages/lightgbm/sklearn.py in fit(self, X, y, sample_weight, init_score, group, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_group, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks, init_model)
#     756             init_model=init_model,
#     757             feature_name=feature_name,
# --> 758             callbacks=callbacks
#     759         )
#     760
#
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py in train(params, train_set, num_boost_round, valid_sets, valid_names, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, evals_result, verbose_eval, learning_rates, keep_training_booster, callbacks)
#     290                                     evaluation_result_list=None))
#     291
# --> 292         booster.update(fobj=fobj)
#     293
#     294         evaluation_result_list = []
#
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py in update(self, train_set, fobj)
#    3021             _safe_call(_LIB.LGBM_BoosterUpdateOneIter(
#    3022                 self.handle,
# -> 3023                 ctypes.byref(is_finished)))
#    3024             self.__is_predicted_cur_iter = [False for _ in range(self.__num_dataset)]
#    3025             return is_finished.value == 1
#
# KeyboardInterrupt:

# %%
lgbm_model = lgbm.LGBMRegressor()
lgbm_model.fit(f_X, f_y)
y_preds_val_lgbm = lgbm_model.predict(X_val)
rmse = mean_squared_error(y_val, y_preds_val_lgbm, squared=False)
rmse
# Out:
# 75316.96471475216

# %%
xgb_model = xgb.XGBRegressor()
xgb_model.fit(f_X, f_y)
y_preds_val_xgb = xgb_model.predict(X_val)
rmse = mean_squared_error(y_val, y_preds_val_xgb, squared=False)
rmse
# Out:
# 96701.27300983373

# %%
cat_model = catboost.CatBoostRegressor()
cat_model.fit(f_X, f_y, verbose=False)
y_preds_val_cat = cat_model.predict(X_val)
rmse = mean_squared_error(y_val, y_preds_val_cat, squared=False)
rmse
# Out:
# 64595.906140480845

# %%
xgb_preds = xgb_model.predict(test)
lgbm_preds = lgbm_model.predict(test)
cat_preds = cat_model.predict(test)

# %%
y_preds_final = xgb_preds

# %%
# xgb
submission = pd.DataFrame({"id": test_idx, "price": y_preds_final})
submission.head()
# Out:
#       id        price
# 0  22730  4760994.000
# 1  22731  6197591.000
# 2  22732  9066677.000
# 3  22733  1633763.875
# 4  22734  6760227.500

# %%
# # cat
# submission = pd.DataFrame({"id": test_idx, "price": y_preds_final})
# submission.head()
# Out:
#       id         price
# 0  22730  4.754707e+06
# 1  22731  6.225202e+06
# 2  22732  9.067827e+06
# 3  22733  1.605656e+06
# 4  22734  6.736176e+06

# %%
# submission = pd.DataFrame({"id": test_idx, "price": y_preds_final})
# submission.head()
# Out:
#       id        price
# 0  22730  4765106.000
# 1  22731  6203692.000
# 2  22732  9070060.000
# 3  22733  1610015.375
# 4  22734  6775811.000

# %%
submission.to_csv("submission.csv", index=False)
